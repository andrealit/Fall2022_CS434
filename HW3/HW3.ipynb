# %%
import numpy as np

import matplotlib.pyplot as plt
import logging
logging.basicConfig(
    format='%(asctime)s %(levelname)-8s %(message)s',
    level=logging.INFO,
    datefmt='%Y-%m-%d %H:%M:%S')
import matplotlib
font = {'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)

# %%
# GLOBAL PARAMETERS FOR STOCHASTIC GRADIENT DESCENT
np.random.seed(1000)
step_size = 0.01
batch_size = 200
max_epochs = 2000

# GLOBAL PARAMETERS FOR NETWORK ARCHITECTURE
number_of_layers = 2
width_of_layers = 16  # only matters if number of layers > 1
activation = "ReLU"

# %%
def main():

  # Load data and display an example
  X_train, Y_train, X_val, Y_val, X_test = loadData()
  displayExample(X_train[np.random.randint(0,len(X_train))])


  # Build a network with input feature dimensions, output feature dimension,
  # hidden dimension, and number of layers as specified below
  net = FeedForwardNeuralNetwork(X_train.shape[1],10,width_of_layers,number_of_layers, activation=activation)

  # Some lists for book-keeping for plotting later
  losses = []
  val_losses = []
  accs = []
  val_accs = []


  # Loss function
  lossFunc = CrossEntropySoftmax()

  # Indicies we will use to shuffle data randomly
  inds = np.arange(len(X_train))
  for i in range(max_epochs):
    
    # Shuffled indicies so we go through data in new random batches
    np.random.shuffle(inds)

    # Go through all datapoints once (aka an epoch)
    j = 0
    acc_running = loss_running = 0
    while j < len(X_train):

      # Select the members of this random batch
      b = min(batch_size, len(X_train)-j)
      X_batch = X_train[inds[j:j+b]]
      Y_batch = Y_train[inds[j:j+b]].astype(np.int)
    
      # Compute the scores for our 10 classes using our model
      logits = net.forward(X_batch)
      loss = lossFunc.forward(logits, Y_batch)
      acc = np.mean( np.argmax(logits,axis=1)[:,np.newaxis] == Y_batch)
      
      # Compute gradient of Cross-Entropy Loss with respect to logits
      loss_grad = lossFunc.backward()

      # Pass gradient back through networks
      net.backward(loss_grad)

      # Take a step of gradient descent
      net.step(step_size)

      #Record losses and accuracy then move to next batch
      losses.append(loss)
      accs.append(acc)
      loss_running += loss*b
      acc_running += acc*b

      j+=batch_size

    # Evaluate performance on validation. This function looks very similar to the training loop above, 
    vloss, vacc = evaluateValidation(net, X_val, Y_val, batch_size)
    val_losses.append(vloss)
    val_accs.append(vacc)
    
    # Print out the average stats over this epoch
    logging.info("[Epoch {:3}]   Loss:  {:8.4}     Train Acc:  {:8.4}%      Val Acc:  {:8.4}%".format(i,loss_running/len(X_train), acc_running / len(X_train)*100,vacc*100))

    


  fig, ax1 = plt.subplots(figsize=(16,9))
  color = 'tab:red'
  ax1.plot(range(len(losses)), losses, c=color, alpha=0.25, label="Train Loss")
  ax1.plot([np.ceil((i+1)*len(X_train)/batch_size) for i in range(len(val_losses))], val_losses,c="red", label="Val. Loss")
  ax1.set_xlabel("Iterations")
  ax1.set_ylabel("Avg. Cross-Entropy Loss", c=color)
  ax1.tick_params(axis='y', labelcolor=color)
  ax1.set_ylim(-0.01,3)

  ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

  color = 'tab:blue'
  ax2.plot(range(len(losses)), accs, c=color, label="Train Acc.", alpha=0.25)
  ax2.plot([np.ceil((i+1)*len(X_train)/batch_size) for i in range(len(val_accs))], val_accs,c="blue", label="Val. Acc.")
  ax2.set_ylabel(" Accuracy", c=color)
  ax2.tick_params(axis='y', labelcolor=color)
  ax2.set_ylim(-0.01,1.01)

  fig.tight_layout()  # otherwise the right y-label is slightly clipped
  ax1.legend(loc="center")
  ax2.legend(loc="center right")
  plt.show()


  ################################
  # Q7 Evaluate on Test
  ################################
  size = len(X_test)
  rowN = np.arange(0,size)
  rowN = rowN[:,None]

  test_out = np.argmax(net.forward(X_test), axis=1)[:,np.newaxis]    
  test_out = np.hstack((rowN, test_out))

  np.savetxt("test_prediction_hw3.csv", test_out, delimiter=",", header="id,digit", fmt='%i', comments='')


class LinearLayer:

  # Initialize our layer with (input_dim, output_dim) weight matrix and a (1,output_dim) bias vector
  def __init__(self, input_dim, output_dim):
    self.weights = np.random.randn(input_dim, output_dim)* np.sqrt(2. / input_dim)
    self.bias = np.ones( (1,output_dim) )*0.5

  # During the forward pass, we simply compute Xw+b
  def forward(self, input):
    self.input = input #Storing X
    return  self.input@self.weights + self.bias

  #################################################
  # Q3 Implementing Backward Pass for Linear
  #################################################
  def backward(self, grad):
    self.grad_weights = self.input.T@grad
    self.grad_bias = np.sum(grad, axis=0)
    return grad@self.weights.T
    
  def step(self, step_size):
    self.weights -= step_size*self.grad_weights
    self.bias -= step_size*self.grad_bias


###############################################
# Instructor code below. Worth understanding
# but don't need to modify for base assignment
###############################################



class FeedForwardNeuralNetwork:

  def __init__(self, input_dim, output_dim, hidden_dim, num_layers, activation="ReLU"):

    if num_layers == 1:
      self.layers = [LinearLayer(input_dim, output_dim)]
    else:
      self.layers = [LinearLayer(input_dim, hidden_dim)]
      self.layers.append(Sigmoid() if activation=="Sigmoid" else ReLU())
      for i in range(num_layers-2):
        self.layers.append(LinearLayer(hidden_dim, hidden_dim))
        self.layers.append(Sigmoid() if activation=="Sigmoid" else ReLU())
      self.layers.append(LinearLayer(hidden_dim, output_dim))

  def forward(self, X):
    for layer in self.layers:
      X = layer.forward(X)
    return X

  def backward(self, grad):
    for layer in reversed(self.layers):
      grad = layer.backward(grad)

  def step(self, step_size=0.001):
    for layer in self.layers:
      layer.step(step_size)





# Sigmoid or Logistic Activation Function
class Sigmoid:

  # Given the input, apply the sigmoid function
  # store the output value for use in the backwards pass
  def forward(self, input):
    self.act = 1/(1+np.exp(-input))
    return self.act
  
  # Compute the gradient of the output with respect to the input
  # self.act*(1-self.act) and then multiply by the loss gradient with 
  # respect to the output to produce the loss gradient with respect to the input
  def backward(self, grad):
    return grad * self.act * (1-self.act)

  # The Sigmoid has no parameters so nothing to do during a gradient descent step
  def step(self,step_size):
    return

# Rectified Linear Unit Activation Function
class ReLU:

  # Forward pass is max(0,input)
  def forward(self, input):
    self.mask = (input > 0)
    return input * self.mask
  
  # Backward pass masks out same elements
  def backward(self, grad):
    return grad * self.mask

  # No parameters so nothing to do during a gradient descent step
  def step(self,step_size):
    return



#####################################################
# Utility Functions for Computing Loss / Val Metrics
#####################################################
def softmax(x):
  x -= np.max(x,axis=1)[:,np.newaxis]  # Numerical stability trick
  return np.exp(x) / (np.sum(np.exp(x),axis=1)[:,np.newaxis])


class CrossEntropySoftmax:

  def forward(self, logits, labels):
    self.probs = softmax(logits)
    self.labels = labels
    return -np.mean(np.log(self.probs[np.arange(len(self.probs))[:,np.newaxis],labels]+0.00001))

  def backward(self):
    grad = self.probs
    grad[np.arange(len(self.probs))[:,np.newaxis],self.labels] -=  1
    return  grad.astype(np.float64)/len(self.probs)


def evaluateValidation(model, X_val, Y_val, batch_size):
  val_loss_running = 0
  val_acc_running = 0
  j=0

  lossFunc = CrossEntropySoftmax()

  while j < len(X_val):
    b = min(batch_size, len(X_val)-j)
    X_batch = X_val[j:j+b]
    Y_batch = Y_val[j:j+b].astype(np.int)
   
    logits = model.forward(X_batch)
    loss = lossFunc.forward(logits, Y_batch)
    acc = np.mean( np.argmax(logits,axis=1)[:,np.newaxis] == Y_batch)

    val_loss_running += loss*b
    val_acc_running += acc*b
       
    j+=batch_size

  return val_loss_running/len(X_val), val_acc_running/len(X_val)







#####################################################
# Utility Functions for Loading and Displaying Data
#####################################################
def loadData(normalize = True):
  train = np.loadtxt("mnist_small_train.csv", delimiter=",", dtype=np.float64)
  val = np.loadtxt("mnist_small_val.csv", delimiter=",", dtype=np.float64)
  test = np.loadtxt("mnist_small_test.csv", delimiter=",", dtype=np.float64)

  # Normalize Our Data
  if normalize:
    X_train = train[:,:-1]/256-0.5
    X_val = val[:,:-1]/256-0.5
    X_test = test/256-0.5
  else:
    X_train = train[:,:-1]
    X_val = val[:,:-1]
    X_test = test

  Y_train = train[:,-1].astype(np.int)[:,np.newaxis]
  Y_val = val[:,-1].astype(np.int)[:,np.newaxis]

  logging.info("Loaded train: " + str(X_train.shape))
  logging.info("Loaded val: " + str(X_val.shape))
  logging.info("Loaded test: "+ str(X_test.shape)) 

  return X_train, Y_train, X_val, Y_val, X_test


def displayExample(x):
  plt.imshow(x.reshape(28,28),cmap="gray")
  plt.show()


if __name__=="__main__":
  main()
# Out:
# /var/folders/j7/v7fxqplj159bfs5m8bw5sdn00000gn/T/ipykernel_57331/4243143198.py:277: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = train[:,-1].astype(np.int)[:,np.newaxis]
# /var/folders/j7/v7fxqplj159bfs5m8bw5sdn00000gn/T/ipykernel_57331/4243143198.py:278: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_val = val[:,-1].astype(np.int)[:,np.newaxis]
# 2022-11-15 11:09:54 INFO     Loaded train: (5000, 784)
# 2022-11-15 11:09:54 INFO     Loaded val: (1000, 784)
# 2022-11-15 11:09:54 INFO     Loaded test: (4220, 784)
# /var/folders/j7/v7fxqplj159bfs5m8bw5sdn00000gn/T/ipykernel_57331/4243143198.py:37: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_batch = Y_train[inds[j:j+b]].astype(np.int)
# /var/folders/j7/v7fxqplj159bfs5m8bw5sdn00000gn/T/ipykernel_57331/4243143198.py:240: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_batch = Y_val[j:j+b].astype(np.int)
# 2022-11-15 11:09:54 INFO     [Epoch   0]   Loss:     2.338     Train Acc:     16.96%      Val Acc:      19.4%
# 2022-11-15 11:09:54 INFO     [Epoch   1]   Loss:     2.167     Train Acc:     25.02%      Val Acc:      31.2%
# 2022-11-15 11:09:54 INFO     [Epoch   2]   Loss:     2.053     Train Acc:     34.52%      Val Acc:      37.3%
# 2022-11-15 11:09:54 INFO     [Epoch   3]   Loss:     1.935     Train Acc:     41.54%      Val Acc:      43.7%
# 2022-11-15 11:09:54 INFO     [Epoch   4]   Loss:     1.818     Train Acc:     47.72%      Val Acc:      49.4%
# 2022-11-15 11:09:54 INFO     [Epoch   5]   Loss:     1.707     Train Acc:     54.14%      Val Acc:      58.7%
# 2022-11-15 11:09:54 INFO     [Epoch   6]   Loss:     1.601     Train Acc:     60.12%      Val Acc:      65.3%
# 2022-11-15 11:09:54 INFO     [Epoch   7]   Loss:     1.502     Train Acc:     64.42%      Val Acc:      69.1%
# 2022-11-15 11:09:54 INFO     [Epoch   8]   Loss:     1.409     Train Acc:     67.38%      Val Acc:      71.0%
# 2022-11-15 11:09:54 INFO     [Epoch   9]   Loss:     1.324     Train Acc:     69.22%      Val Acc:      73.2%
# 2022-11-15 11:09:54 INFO     [Epoch  10]   Loss:     1.243     Train Acc:     70.68%      Val Acc:      74.1%
# 2022-11-15 11:09:54 INFO     [Epoch  11]   Loss:     1.169     Train Acc:     71.92%      Val Acc:      75.7%
# 2022-11-15 11:09:54 INFO     [Epoch  12]   Loss:       1.1     Train Acc:     73.28%      Val Acc:      77.5%
# 2022-11-15 11:09:54 INFO     [Epoch  13]   Loss:     1.038     Train Acc:     74.86%      Val Acc:      79.2%
# 2022-11-15 11:09:54 INFO     [Epoch  14]   Loss:     0.983     Train Acc:     76.12%      Val Acc:      80.2%
# 2022-11-15 11:09:55 INFO     [Epoch  15]   Loss:    0.9349     Train Acc:     77.34%      Val Acc:      80.9%
# 2022-11-15 11:09:55 INFO     [Epoch  16]   Loss:     0.892     Train Acc:     77.94%      Val Acc:      82.0%
# 2022-11-15 11:09:55 INFO     [Epoch  17]   Loss:    0.8533     Train Acc:     78.84%      Val Acc:      82.2%
# 2022-11-15 11:09:55 INFO     [Epoch  18]   Loss:     0.819     Train Acc:      79.4%      Val Acc:      82.8%
# 2022-11-15 11:09:55 INFO     [Epoch  19]   Loss:    0.7889     Train Acc:     80.46%      Val Acc:      83.1%
# 2022-11-15 11:09:55 INFO     [Epoch  20]   Loss:    0.7606     Train Acc:      81.2%      Val Acc:      83.7%
# 2022-11-15 11:09:55 INFO     [Epoch  21]   Loss:    0.7348     Train Acc:     81.78%      Val Acc:      83.9%
# 2022-11-15 11:09:55 INFO     [Epoch  22]   Loss:    0.7121     Train Acc:     82.22%      Val Acc:      84.5%
# 2022-11-15 11:09:55 INFO     [Epoch  23]   Loss:    0.6907     Train Acc:     82.64%      Val Acc:      85.3%
# 2022-11-15 11:09:55 INFO     [Epoch  24]   Loss:    0.6705     Train Acc:     83.28%      Val Acc:      85.2%
# 2022-11-15 11:09:55 INFO     [Epoch  25]   Loss:     0.653     Train Acc:     83.58%      Val Acc:      85.8%
# 2022-11-15 11:09:55 INFO     [Epoch  26]   Loss:    0.6366     Train Acc:     83.88%      Val Acc:      86.3%
# 2022-11-15 11:09:55 INFO     [Epoch  27]   Loss:    0.6214     Train Acc:     84.24%      Val Acc:      86.5%
# 2022-11-15 11:09:55 INFO     [Epoch  28]   Loss:    0.6066     Train Acc:     84.54%      Val Acc:      86.9%
# 2022-11-15 11:09:55 INFO     [Epoch  29]   Loss:    0.5937     Train Acc:     84.46%      Val Acc:      87.5%
# 2022-11-15 11:09:55 INFO     [Epoch  30]   Loss:    0.5811     Train Acc:     84.98%      Val Acc:      87.5%
# 2022-11-15 11:09:55 INFO     [Epoch  31]   Loss:    0.5697     Train Acc:     85.04%      Val Acc:      88.0%
# 2022-11-15 11:09:55 INFO     [Epoch  32]   Loss:    0.5585     Train Acc:     85.48%      Val Acc:      88.4%
# 2022-11-15 11:09:55 INFO     [Epoch  33]   Loss:    0.5478     Train Acc:     85.62%      Val Acc:      88.5%
# 2022-11-15 11:09:55 INFO     [Epoch  34]   Loss:    0.5383     Train Acc:     85.84%      Val Acc:      88.7%
# 2022-11-15 11:09:55 INFO     [Epoch  35]   Loss:    0.5292     Train Acc:     85.76%      Val Acc:      88.8%
# 2022-11-15 11:09:55 INFO     [Epoch  36]   Loss:    0.5209     Train Acc:     86.14%      Val Acc:      89.1%
# 2022-11-15 11:09:55 INFO     [Epoch  37]   Loss:    0.5124     Train Acc:     86.36%      Val Acc:      89.3%
# 2022-11-15 11:09:55 INFO     [Epoch  38]   Loss:    0.5045     Train Acc:     86.42%      Val Acc:      89.0%
# 2022-11-15 11:09:55 INFO     [Epoch  39]   Loss:    0.4971     Train Acc:      86.7%      Val Acc:      89.3%
# 2022-11-15 11:09:55 INFO     [Epoch  40]   Loss:    0.4899     Train Acc:     86.54%      Val Acc:      89.5%
# 2022-11-15 11:09:55 INFO     [Epoch  41]   Loss:    0.4836     Train Acc:     86.84%      Val Acc:      89.7%
# 2022-11-15 11:09:55 INFO     [Epoch  42]   Loss:    0.4775     Train Acc:      87.3%      Val Acc:      89.3%
# 2022-11-15 11:09:55 INFO     [Epoch  43]   Loss:     0.471     Train Acc:     87.38%      Val Acc:      89.6%
# 2022-11-15 11:09:55 INFO     [Epoch  44]   Loss:     0.465     Train Acc:     87.34%      Val Acc:      89.8%
# 2022-11-15 11:09:56 INFO     [Epoch  45]   Loss:    0.4596     Train Acc:     87.56%      Val Acc:      90.0%
# 2022-11-15 11:09:56 INFO     [Epoch  46]   Loss:    0.4542     Train Acc:     87.76%      Val Acc:      89.9%
# 2022-11-15 11:09:56 INFO     [Epoch  47]   Loss:    0.4489     Train Acc:      87.9%      Val Acc:      89.8%
# 2022-11-15 11:09:56 INFO     [Epoch  48]   Loss:    0.4446     Train Acc:     88.02%      Val Acc:      90.1%
# 2022-11-15 11:09:56 INFO     [Epoch  49]   Loss:    0.4398     Train Acc:     88.02%      Val Acc:      89.8%
# 2022-11-15 11:09:56 INFO     [Epoch  50]   Loss:    0.4356     Train Acc:     88.28%      Val Acc:      90.2%
# 2022-11-15 11:09:56 INFO     [Epoch  51]   Loss:    0.4311     Train Acc:     88.38%      Val Acc:      90.1%
# 2022-11-15 11:09:56 INFO     [Epoch  52]   Loss:    0.4266     Train Acc:      88.3%      Val Acc:      90.2%
# 2022-11-15 11:09:56 INFO     [Epoch  53]   Loss:    0.4228     Train Acc:      88.7%      Val Acc:      90.5%
# 2022-11-15 11:09:56 INFO     [Epoch  54]   Loss:     0.419     Train Acc:      88.6%      Val Acc:      90.1%
# 2022-11-15 11:09:56 INFO     [Epoch  55]   Loss:     0.415     Train Acc:     88.76%      Val Acc:      90.1%
# 2022-11-15 11:09:56 INFO     [Epoch  56]   Loss:    0.4111     Train Acc:     88.92%      Val Acc:      90.4%
# 2022-11-15 11:09:56 INFO     [Epoch  57]   Loss:    0.4079     Train Acc:     88.98%      Val Acc:      90.3%
# 2022-11-15 11:09:56 INFO     [Epoch  58]   Loss:    0.4042     Train Acc:      89.0%      Val Acc:      90.4%
# 2022-11-15 11:09:56 INFO     [Epoch  59]   Loss:    0.4008     Train Acc:     89.08%      Val Acc:      90.6%
# 2022-11-15 11:09:56 INFO     [Epoch  60]   Loss:    0.3978     Train Acc:      89.2%      Val Acc:      90.5%
# 2022-11-15 11:09:56 INFO     [Epoch  61]   Loss:    0.3945     Train Acc:     89.22%      Val Acc:      90.8%
# 2022-11-15 11:09:56 INFO     [Epoch  62]   Loss:    0.3915     Train Acc:     89.04%      Val Acc:      90.5%
# 2022-11-15 11:09:56 INFO     [Epoch  63]   Loss:    0.3889     Train Acc:     89.28%      Val Acc:      90.6%
# 2022-11-15 11:09:56 INFO     [Epoch  64]   Loss:    0.3856     Train Acc:     89.36%      Val Acc:      90.8%
# 2022-11-15 11:09:56 INFO     [Epoch  65]   Loss:    0.3831     Train Acc:     89.24%      Val Acc:      90.5%
# 2022-11-15 11:09:56 INFO     [Epoch  66]   Loss:    0.3803     Train Acc:     89.58%      Val Acc:      90.5%
# 2022-11-15 11:09:56 INFO     [Epoch  67]   Loss:    0.3778     Train Acc:      89.5%      Val Acc:      90.1%
# 2022-11-15 11:09:56 INFO     [Epoch  68]   Loss:    0.3752     Train Acc:      89.6%      Val Acc:      90.6%
# 2022-11-15 11:09:56 INFO     [Epoch  69]   Loss:    0.3727     Train Acc:      89.7%      Val Acc:      90.6%
# 2022-11-15 11:09:56 INFO     [Epoch  70]   Loss:    0.3699     Train Acc:     89.68%      Val Acc:      90.7%
# 2022-11-15 11:09:56 INFO     [Epoch  71]   Loss:     0.368     Train Acc:     89.64%      Val Acc:      90.6%
# 2022-11-15 11:09:56 INFO     [Epoch  72]   Loss:    0.3654     Train Acc:     89.86%      Val Acc:      90.9%
# 2022-11-15 11:09:56 INFO     [Epoch  73]   Loss:    0.3631     Train Acc:     90.04%      Val Acc:      90.6%
# 2022-11-15 11:09:56 INFO     [Epoch  74]   Loss:    0.3611     Train Acc:     90.12%      Val Acc:      91.0%
# 2022-11-15 11:09:56 INFO     [Epoch  75]   Loss:     0.359     Train Acc:      90.1%      Val Acc:      90.8%
# 2022-11-15 11:09:56 INFO     [Epoch  76]   Loss:     0.357     Train Acc:     90.22%      Val Acc:      91.0%
# 2022-11-15 11:09:56 INFO     [Epoch  77]   Loss:    0.3545     Train Acc:     90.26%      Val Acc:      90.6%
# 2022-11-15 11:09:57 INFO     [Epoch  78]   Loss:    0.3527     Train Acc:     90.32%      Val Acc:      90.8%
# 2022-11-15 11:09:57 INFO     [Epoch  79]   Loss:    0.3508     Train Acc:     90.36%      Val Acc:      90.5%
# 2022-11-15 11:09:57 INFO     [Epoch  80]   Loss:    0.3493     Train Acc:      90.4%      Val Acc:      90.6%
# 2022-11-15 11:09:57 INFO     [Epoch  81]   Loss:    0.3467     Train Acc:     90.54%      Val Acc:      90.9%
# 2022-11-15 11:09:57 INFO     [Epoch  82]   Loss:    0.3452     Train Acc:     90.64%      Val Acc:      90.7%
# 2022-11-15 11:09:57 INFO     [Epoch  83]   Loss:    0.3436     Train Acc:     90.54%      Val Acc:      91.0%
# 2022-11-15 11:09:57 INFO     [Epoch  84]   Loss:    0.3417     Train Acc:      90.4%      Val Acc:      90.8%
# 2022-11-15 11:09:57 INFO     [Epoch  85]   Loss:      0.34     Train Acc:     90.76%      Val Acc:      90.5%
# 2022-11-15 11:09:57 INFO     [Epoch  86]   Loss:    0.3378     Train Acc:     90.66%      Val Acc:      90.7%
# 2022-11-15 11:09:57 INFO     [Epoch  87]   Loss:    0.3367     Train Acc:     90.76%      Val Acc:      90.6%
# 2022-11-15 11:09:57 INFO     [Epoch  88]   Loss:    0.3349     Train Acc:     90.82%      Val Acc:      91.0%
# 2022-11-15 11:09:57 INFO     [Epoch  89]   Loss:    0.3333     Train Acc:     90.94%      Val Acc:      91.0%
# 2022-11-15 11:09:57 INFO     [Epoch  90]   Loss:    0.3319     Train Acc:      91.0%      Val Acc:      90.7%
# 2022-11-15 11:09:57 INFO     [Epoch  91]   Loss:    0.3303     Train Acc:     90.96%      Val Acc:      90.8%
# 2022-11-15 11:09:57 INFO     [Epoch  92]   Loss:    0.3287     Train Acc:     91.06%      Val Acc:      90.8%
# 2022-11-15 11:09:57 INFO     [Epoch  93]   Loss:    0.3271     Train Acc:     90.96%      Val Acc:      90.8%
# 2022-11-15 11:09:57 INFO     [Epoch  94]   Loss:    0.3256     Train Acc:     90.82%      Val Acc:      90.9%
# 2022-11-15 11:09:57 INFO     [Epoch  95]   Loss:    0.3245     Train Acc:     91.12%      Val Acc:      90.6%
# 2022-11-15 11:09:57 INFO     [Epoch  96]   Loss:     0.323     Train Acc:      91.2%      Val Acc:      90.5%
# 2022-11-15 11:09:57 INFO     [Epoch  97]   Loss:    0.3212     Train Acc:     91.26%      Val Acc:      90.6%
# 2022-11-15 11:09:57 INFO     [Epoch  98]   Loss:    0.3205     Train Acc:      91.1%      Val Acc:      90.6%
# 2022-11-15 11:09:57 INFO     [Epoch  99]   Loss:    0.3186     Train Acc:     91.26%      Val Acc:      91.1%
# 2022-11-15 11:09:57 INFO     [Epoch 100]   Loss:    0.3177     Train Acc:     91.32%      Val Acc:      90.8%
# 2022-11-15 11:09:57 INFO     [Epoch 101]   Loss:    0.3164     Train Acc:      91.3%      Val Acc:      90.6%
# 2022-11-15 11:09:57 INFO     [Epoch 102]   Loss:    0.3146     Train Acc:     91.48%      Val Acc:      91.1%
# 2022-11-15 11:09:57 INFO     [Epoch 103]   Loss:    0.3141     Train Acc:     91.56%      Val Acc:      90.7%
# 2022-11-15 11:09:57 INFO     [Epoch 104]   Loss:    0.3125     Train Acc:     91.52%      Val Acc:      90.9%
# 2022-11-15 11:09:57 INFO     [Epoch 105]   Loss:    0.3112     Train Acc:     91.78%      Val Acc:      91.0%
# 2022-11-15 11:09:57 INFO     [Epoch 106]   Loss:    0.3101     Train Acc:     91.74%      Val Acc:      90.8%
# 2022-11-15 11:09:57 INFO     [Epoch 107]   Loss:     0.309     Train Acc:     91.56%      Val Acc:      90.8%
# 2022-11-15 11:09:57 INFO     [Epoch 108]   Loss:    0.3078     Train Acc:     91.76%      Val Acc:      91.0%
# 2022-11-15 11:09:57 INFO     [Epoch 109]   Loss:    0.3067     Train Acc:      91.8%      Val Acc:      90.7%
# 2022-11-15 11:09:58 INFO     [Epoch 110]   Loss:    0.3054     Train Acc:     91.82%      Val Acc:      91.4%
# 2022-11-15 11:09:58 INFO     [Epoch 111]   Loss:    0.3044     Train Acc:     91.76%      Val Acc:      90.9%
# 2022-11-15 11:09:58 INFO     [Epoch 112]   Loss:    0.3034     Train Acc:     91.94%      Val Acc:      91.1%
# 2022-11-15 11:09:58 INFO     [Epoch 113]   Loss:    0.3023     Train Acc:     91.86%      Val Acc:      91.1%
# 2022-11-15 11:09:58 INFO     [Epoch 114]   Loss:    0.3013     Train Acc:     91.78%      Val Acc:      90.7%
# 2022-11-15 11:09:58 INFO     [Epoch 115]   Loss:    0.2998     Train Acc:     91.86%      Val Acc:      91.3%
# 2022-11-15 11:09:58 INFO     [Epoch 116]   Loss:    0.2988     Train Acc:     92.04%      Val Acc:      91.4%
# 2022-11-15 11:09:58 INFO     [Epoch 117]   Loss:    0.2978     Train Acc:     92.08%      Val Acc:      91.0%
# 2022-11-15 11:09:58 INFO     [Epoch 118]   Loss:    0.2971     Train Acc:     92.06%      Val Acc:      91.5%
# 2022-11-15 11:09:58 INFO     [Epoch 119]   Loss:    0.2958     Train Acc:     92.12%      Val Acc:      91.1%
# 2022-11-15 11:09:58 INFO     [Epoch 120]   Loss:    0.2949     Train Acc:     92.06%      Val Acc:      91.0%
# 2022-11-15 11:09:58 INFO     [Epoch 121]   Loss:    0.2939     Train Acc:      92.0%      Val Acc:      91.2%
# 2022-11-15 11:09:58 INFO     [Epoch 122]   Loss:    0.2932     Train Acc:     92.16%      Val Acc:      90.9%
# 2022-11-15 11:09:58 INFO     [Epoch 123]   Loss:    0.2921     Train Acc:      92.1%      Val Acc:      90.9%
# 2022-11-15 11:09:58 INFO     [Epoch 124]   Loss:    0.2911     Train Acc:     92.34%      Val Acc:      90.9%
# 2022-11-15 11:09:58 INFO     [Epoch 125]   Loss:    0.2901     Train Acc:     92.24%      Val Acc:      90.9%
# 2022-11-15 11:09:58 INFO     [Epoch 126]   Loss:    0.2893     Train Acc:     92.24%      Val Acc:      91.1%
# 2022-11-15 11:09:58 INFO     [Epoch 127]   Loss:    0.2886     Train Acc:     92.16%      Val Acc:      91.1%
# 2022-11-15 11:09:58 INFO     [Epoch 128]   Loss:    0.2878     Train Acc:     92.28%      Val Acc:      91.5%
# 2022-11-15 11:09:58 INFO     [Epoch 129]   Loss:    0.2869     Train Acc:     92.32%      Val Acc:      90.9%
# 2022-11-15 11:09:58 INFO     [Epoch 130]   Loss:     0.286     Train Acc:      92.5%      Val Acc:      91.2%
# 2022-11-15 11:09:58 INFO     [Epoch 131]   Loss:    0.2849     Train Acc:      92.3%      Val Acc:      91.0%
# 2022-11-15 11:09:58 INFO     [Epoch 132]   Loss:    0.2841     Train Acc:     92.32%      Val Acc:      91.6%
# 2022-11-15 11:09:58 INFO     [Epoch 133]   Loss:    0.2835     Train Acc:      92.3%      Val Acc:      91.5%
# 2022-11-15 11:09:58 INFO     [Epoch 134]   Loss:    0.2826     Train Acc:     92.42%      Val Acc:      90.9%
# 2022-11-15 11:09:58 INFO     [Epoch 135]   Loss:    0.2814     Train Acc:      92.5%      Val Acc:      91.2%
# 2022-11-15 11:09:58 INFO     [Epoch 136]   Loss:    0.2806     Train Acc:     92.48%      Val Acc:      90.7%
# 2022-11-15 11:09:58 INFO     [Epoch 137]   Loss:      0.28     Train Acc:     92.52%      Val Acc:      90.9%
# 2022-11-15 11:09:58 INFO     [Epoch 138]   Loss:    0.2792     Train Acc:     92.56%      Val Acc:      91.1%
# 2022-11-15 11:09:58 INFO     [Epoch 139]   Loss:    0.2783     Train Acc:      92.5%      Val Acc:      91.3%
# 2022-11-15 11:09:58 INFO     [Epoch 140]   Loss:    0.2775     Train Acc:     92.46%      Val Acc:      91.1%
# 2022-11-15 11:09:59 INFO     [Epoch 141]   Loss:    0.2768     Train Acc:     92.62%      Val Acc:      91.2%
# 2022-11-15 11:09:59 INFO     [Epoch 142]   Loss:    0.2757     Train Acc:     92.66%      Val Acc:      90.9%
# 2022-11-15 11:09:59 INFO     [Epoch 143]   Loss:    0.2756     Train Acc:      92.6%      Val Acc:      91.5%
# 2022-11-15 11:09:59 INFO     [Epoch 144]   Loss:    0.2746     Train Acc:     92.62%      Val Acc:      91.5%
# 2022-11-15 11:09:59 INFO     [Epoch 145]   Loss:    0.2737     Train Acc:     92.48%      Val Acc:      91.1%
# 2022-11-15 11:09:59 INFO     [Epoch 146]   Loss:    0.2732     Train Acc:     92.76%      Val Acc:      91.1%
# 2022-11-15 11:09:59 INFO     [Epoch 147]   Loss:    0.2723     Train Acc:     92.62%      Val Acc:      91.1%
# 2022-11-15 11:09:59 INFO     [Epoch 148]   Loss:    0.2717     Train Acc:      92.7%      Val Acc:      91.0%
# 2022-11-15 11:09:59 INFO     [Epoch 149]   Loss:    0.2713     Train Acc:     92.72%      Val Acc:      91.4%
# 2022-11-15 11:09:59 INFO     [Epoch 150]   Loss:    0.2703     Train Acc:     92.92%      Val Acc:      91.4%
# 2022-11-15 11:09:59 INFO     [Epoch 151]   Loss:    0.2695     Train Acc:     92.66%      Val Acc:      91.4%
# 2022-11-15 11:09:59 INFO     [Epoch 152]   Loss:    0.2688     Train Acc:     92.72%      Val Acc:      91.5%
# 2022-11-15 11:09:59 INFO     [Epoch 153]   Loss:    0.2682     Train Acc:     92.86%      Val Acc:      91.5%
# 2022-11-15 11:09:59 INFO     [Epoch 154]   Loss:    0.2674     Train Acc:      92.9%      Val Acc:      91.3%
# 2022-11-15 11:09:59 INFO     [Epoch 155]   Loss:    0.2667     Train Acc:     92.78%      Val Acc:      91.2%
# 2022-11-15 11:09:59 INFO     [Epoch 156]   Loss:    0.2662     Train Acc:      92.9%      Val Acc:      91.1%
# 2022-11-15 11:09:59 INFO     [Epoch 157]   Loss:     0.265     Train Acc:     92.82%      Val Acc:      91.2%
# 2022-11-15 11:09:59 INFO     [Epoch 158]   Loss:    0.2648     Train Acc:     93.06%      Val Acc:      91.1%
# 2022-11-15 11:09:59 INFO     [Epoch 159]   Loss:    0.2639     Train Acc:     92.88%      Val Acc:      91.4%
# 2022-11-15 11:09:59 INFO     [Epoch 160]   Loss:    0.2634     Train Acc:     92.98%      Val Acc:      91.3%
# 2022-11-15 11:09:59 INFO     [Epoch 161]   Loss:    0.2626     Train Acc:     92.94%      Val Acc:      91.2%
# 2022-11-15 11:09:59 INFO     [Epoch 162]   Loss:    0.2622     Train Acc:     92.88%      Val Acc:      91.2%
# 2022-11-15 11:09:59 INFO     [Epoch 163]   Loss:    0.2616     Train Acc:     92.92%      Val Acc:      91.3%
# 2022-11-15 11:09:59 INFO     [Epoch 164]   Loss:    0.2614     Train Acc:     92.94%      Val Acc:      91.3%
# 2022-11-15 11:09:59 INFO     [Epoch 165]   Loss:    0.2602     Train Acc:      93.0%      Val Acc:      91.0%
# 2022-11-15 11:09:59 INFO     [Epoch 166]   Loss:    0.2602     Train Acc:      92.9%      Val Acc:      91.2%
# 2022-11-15 11:09:59 INFO     [Epoch 167]   Loss:    0.2594     Train Acc:     92.94%      Val Acc:      91.4%
# 2022-11-15 11:09:59 INFO     [Epoch 168]   Loss:    0.2584     Train Acc:     93.12%      Val Acc:      91.3%
# 2022-11-15 11:09:59 INFO     [Epoch 169]   Loss:    0.2578     Train Acc:     92.94%      Val Acc:      91.5%
# 2022-11-15 11:09:59 INFO     [Epoch 170]   Loss:    0.2572     Train Acc:      93.1%      Val Acc:      91.3%
# 2022-11-15 11:09:59 INFO     [Epoch 171]   Loss:    0.2568     Train Acc:     93.14%      Val Acc:      91.1%
# 2022-11-15 11:10:00 INFO     [Epoch 172]   Loss:    0.2563     Train Acc:     93.14%      Val Acc:      91.3%
# 2022-11-15 11:10:00 INFO     [Epoch 173]   Loss:    0.2555     Train Acc:     93.06%      Val Acc:      91.3%
# 2022-11-15 11:10:00 INFO     [Epoch 174]   Loss:    0.2549     Train Acc:     93.06%      Val Acc:      91.2%
# 2022-11-15 11:10:00 INFO     [Epoch 175]   Loss:    0.2544     Train Acc:     93.24%      Val Acc:      91.3%
# 2022-11-15 11:10:00 INFO     [Epoch 176]   Loss:    0.2543     Train Acc:     93.08%      Val Acc:      91.2%
# 2022-11-15 11:10:00 INFO     [Epoch 177]   Loss:    0.2534     Train Acc:      93.2%      Val Acc:      91.1%
# 2022-11-15 11:10:00 INFO     [Epoch 178]   Loss:    0.2525     Train Acc:     93.14%      Val Acc:      91.2%
# 2022-11-15 11:10:00 INFO     [Epoch 179]   Loss:     0.252     Train Acc:     93.24%      Val Acc:      91.1%
# 2022-11-15 11:10:00 INFO     [Epoch 180]   Loss:    0.2521     Train Acc:      93.1%      Val Acc:      91.2%
# 2022-11-15 11:10:00 INFO     [Epoch 181]   Loss:    0.2511     Train Acc:      93.3%      Val Acc:      91.4%
# 2022-11-15 11:10:00 INFO     [Epoch 182]   Loss:    0.2507     Train Acc:     93.18%      Val Acc:      91.4%
# 2022-11-15 11:10:00 INFO     [Epoch 183]   Loss:    0.2503     Train Acc:     93.18%      Val Acc:      91.2%
# 2022-11-15 11:10:00 INFO     [Epoch 184]   Loss:    0.2496     Train Acc:     93.28%      Val Acc:      91.3%
# 2022-11-15 11:10:00 INFO     [Epoch 185]   Loss:    0.2489     Train Acc:     93.34%      Val Acc:      91.3%
# 2022-11-15 11:10:00 INFO     [Epoch 186]   Loss:     0.249     Train Acc:     93.42%      Val Acc:      91.4%
# 2022-11-15 11:10:00 INFO     [Epoch 187]   Loss:    0.2479     Train Acc:     93.36%      Val Acc:      91.4%
# 2022-11-15 11:10:00 INFO     [Epoch 188]   Loss:    0.2475     Train Acc:     93.36%      Val Acc:      91.6%
# 2022-11-15 11:10:00 INFO     [Epoch 189]   Loss:     0.247     Train Acc:     93.26%      Val Acc:      91.4%
# 2022-11-15 11:10:00 INFO     [Epoch 190]   Loss:    0.2464     Train Acc:     93.42%      Val Acc:      91.2%
# 2022-11-15 11:10:00 INFO     [Epoch 191]   Loss:     0.246     Train Acc:     93.38%      Val Acc:      91.3%
# 2022-11-15 11:10:00 INFO     [Epoch 192]   Loss:    0.2452     Train Acc:     93.54%      Val Acc:      91.4%
# 2022-11-15 11:10:00 INFO     [Epoch 193]   Loss:    0.2452     Train Acc:     93.38%      Val Acc:      91.3%
# 2022-11-15 11:10:00 INFO     [Epoch 194]   Loss:    0.2446     Train Acc:     93.34%      Val Acc:      91.6%
# 2022-11-15 11:10:00 INFO     [Epoch 195]   Loss:     0.244     Train Acc:      93.5%      Val Acc:      91.4%
# 2022-11-15 11:10:00 INFO     [Epoch 196]   Loss:    0.2432     Train Acc:     93.34%      Val Acc:      91.2%
# 2022-11-15 11:10:00 INFO     [Epoch 197]   Loss:     0.243     Train Acc:     93.42%      Val Acc:      91.5%
# 2022-11-15 11:10:00 INFO     [Epoch 198]   Loss:    0.2426     Train Acc:      93.5%      Val Acc:      91.4%
# 2022-11-15 11:10:01 INFO     [Epoch 199]   Loss:    0.2421     Train Acc:     93.52%      Val Acc:      91.4%
# 2022-11-15 11:10:01 INFO     [Epoch 200]   Loss:    0.2422     Train Acc:     93.54%      Val Acc:      91.4%
# 2022-11-15 11:10:01 INFO     [Epoch 201]   Loss:    0.2412     Train Acc:     93.66%      Val Acc:      91.5%
# 2022-11-15 11:10:01 INFO     [Epoch 202]   Loss:    0.2406     Train Acc:     93.64%      Val Acc:      91.3%
# 2022-11-15 11:10:01 INFO     [Epoch 203]   Loss:    0.2403     Train Acc:     93.58%      Val Acc:      91.3%
# 2022-11-15 11:10:01 INFO     [Epoch 204]   Loss:    0.2397     Train Acc:     93.56%      Val Acc:      91.4%
# 2022-11-15 11:10:01 INFO     [Epoch 205]   Loss:     0.239     Train Acc:      93.6%      Val Acc:      91.5%
# 2022-11-15 11:10:01 INFO     [Epoch 206]   Loss:    0.2387     Train Acc:     93.66%      Val Acc:      91.3%
# 2022-11-15 11:10:01 INFO     [Epoch 207]   Loss:    0.2384     Train Acc:     93.58%      Val Acc:      91.3%
# 2022-11-15 11:10:01 INFO     [Epoch 208]   Loss:    0.2378     Train Acc:     93.66%      Val Acc:      91.3%
# 2022-11-15 11:10:01 INFO     [Epoch 209]   Loss:    0.2376     Train Acc:      93.6%      Val Acc:      91.5%
# 2022-11-15 11:10:01 INFO     [Epoch 210]   Loss:    0.2368     Train Acc:      93.7%      Val Acc:      91.5%
# 2022-11-15 11:10:01 INFO     [Epoch 211]   Loss:    0.2364     Train Acc:     93.68%      Val Acc:      91.4%
# 2022-11-15 11:10:01 INFO     [Epoch 212]   Loss:    0.2363     Train Acc:     93.62%      Val Acc:      91.5%
# 2022-11-15 11:10:01 INFO     [Epoch 213]   Loss:    0.2356     Train Acc:     93.76%      Val Acc:      91.7%
# 2022-11-15 11:10:01 INFO     [Epoch 214]   Loss:    0.2352     Train Acc:     93.64%      Val Acc:      91.3%
# 2022-11-15 11:10:01 INFO     [Epoch 215]   Loss:    0.2346     Train Acc:     93.82%      Val Acc:      91.5%
# 2022-11-15 11:10:01 INFO     [Epoch 216]   Loss:    0.2343     Train Acc:     93.76%      Val Acc:      91.2%
# 2022-11-15 11:10:01 INFO     [Epoch 217]   Loss:    0.2339     Train Acc:     93.74%      Val Acc:      91.4%
# 2022-11-15 11:10:01 INFO     [Epoch 218]   Loss:    0.2336     Train Acc:     93.72%      Val Acc:      91.5%
# 2022-11-15 11:10:01 INFO     [Epoch 219]   Loss:    0.2332     Train Acc:     93.76%      Val Acc:      91.5%
# 2022-11-15 11:10:01 INFO     [Epoch 220]   Loss:    0.2327     Train Acc:     93.82%      Val Acc:      91.2%
# 2022-11-15 11:10:01 INFO     [Epoch 221]   Loss:     0.232     Train Acc:      93.8%      Val Acc:      91.5%
# 2022-11-15 11:10:01 INFO     [Epoch 222]   Loss:    0.2318     Train Acc:      93.8%      Val Acc:      91.3%
# 2022-11-15 11:10:01 INFO     [Epoch 223]   Loss:    0.2312     Train Acc:     93.82%      Val Acc:      91.4%
# 2022-11-15 11:10:01 INFO     [Epoch 224]   Loss:    0.2307     Train Acc:     93.86%      Val Acc:      91.5%
# 2022-11-15 11:10:01 INFO     [Epoch 225]   Loss:    0.2303     Train Acc:     93.94%      Val Acc:      91.2%
# 2022-11-15 11:10:01 INFO     [Epoch 226]   Loss:    0.2301     Train Acc:      93.9%      Val Acc:      91.4%
# 2022-11-15 11:10:01 INFO     [Epoch 227]   Loss:    0.2296     Train Acc:     93.92%      Val Acc:      91.4%
# 2022-11-15 11:10:02 INFO     [Epoch 228]   Loss:    0.2295     Train Acc:     93.92%      Val Acc:      91.2%
# 2022-11-15 11:10:02 INFO     [Epoch 229]   Loss:    0.2287     Train Acc:     94.04%      Val Acc:      91.5%
# 2022-11-15 11:10:02 INFO     [Epoch 230]   Loss:    0.2287     Train Acc:     93.92%      Val Acc:      91.5%
# 2022-11-15 11:10:02 INFO     [Epoch 231]   Loss:    0.2278     Train Acc:     93.86%      Val Acc:      91.6%
# 2022-11-15 11:10:02 INFO     [Epoch 232]   Loss:    0.2279     Train Acc:     93.94%      Val Acc:      91.3%
# 2022-11-15 11:10:02 INFO     [Epoch 233]   Loss:    0.2273     Train Acc:     93.94%      Val Acc:      91.7%
# 2022-11-15 11:10:02 INFO     [Epoch 234]   Loss:    0.2269     Train Acc:     93.96%      Val Acc:      91.5%
# 2022-11-15 11:10:02 INFO     [Epoch 235]   Loss:    0.2266     Train Acc:     94.12%      Val Acc:      91.5%
# 2022-11-15 11:10:02 INFO     [Epoch 236]   Loss:     0.226     Train Acc:      94.0%      Val Acc:      91.4%
# 2022-11-15 11:10:02 INFO     [Epoch 237]   Loss:    0.2257     Train Acc:      94.0%      Val Acc:      91.6%
# 2022-11-15 11:10:02 INFO     [Epoch 238]   Loss:    0.2253     Train Acc:      94.0%      Val Acc:      91.8%
# 2022-11-15 11:10:02 INFO     [Epoch 239]   Loss:    0.2249     Train Acc:     93.96%      Val Acc:      91.8%
# 2022-11-15 11:10:02 INFO     [Epoch 240]   Loss:    0.2243     Train Acc:     94.08%      Val Acc:      91.6%
# 2022-11-15 11:10:02 INFO     [Epoch 241]   Loss:    0.2239     Train Acc:     94.06%      Val Acc:      91.5%
# 2022-11-15 11:10:02 INFO     [Epoch 242]   Loss:    0.2237     Train Acc:     94.08%      Val Acc:      91.7%
# 2022-11-15 11:10:02 INFO     [Epoch 243]   Loss:    0.2234     Train Acc:     94.04%      Val Acc:      91.8%
# 2022-11-15 11:10:02 INFO     [Epoch 244]   Loss:    0.2228     Train Acc:     94.04%      Val Acc:      91.4%
# 2022-11-15 11:10:02 INFO     [Epoch 245]   Loss:    0.2227     Train Acc:      94.1%      Val Acc:      91.5%
# 2022-11-15 11:10:02 INFO     [Epoch 246]   Loss:    0.2221     Train Acc:      94.1%      Val Acc:      91.3%
# 2022-11-15 11:10:02 INFO     [Epoch 247]   Loss:    0.2219     Train Acc:     94.08%      Val Acc:      91.8%
# 2022-11-15 11:10:02 INFO     [Epoch 248]   Loss:    0.2214     Train Acc:     94.06%      Val Acc:      91.7%
# 2022-11-15 11:10:02 INFO     [Epoch 249]   Loss:    0.2212     Train Acc:     94.12%      Val Acc:      91.6%
# 2022-11-15 11:10:02 INFO     [Epoch 250]   Loss:    0.2207     Train Acc:      94.2%      Val Acc:      91.8%
# 2022-11-15 11:10:02 INFO     [Epoch 251]   Loss:    0.2205     Train Acc:     94.18%      Val Acc:      91.8%
# 2022-11-15 11:10:02 INFO     [Epoch 252]   Loss:      0.22     Train Acc:     94.18%      Val Acc:      91.8%
# 2022-11-15 11:10:02 INFO     [Epoch 253]   Loss:    0.2199     Train Acc:     94.28%      Val Acc:      91.6%
# 2022-11-15 11:10:02 INFO     [Epoch 254]   Loss:    0.2188     Train Acc:     94.24%      Val Acc:      91.8%
# 2022-11-15 11:10:02 INFO     [Epoch 255]   Loss:    0.2188     Train Acc:      94.2%      Val Acc:      91.7%
# 2022-11-15 11:10:02 INFO     [Epoch 256]   Loss:    0.2187     Train Acc:     94.26%      Val Acc:      91.8%
# 2022-11-15 11:10:02 INFO     [Epoch 257]   Loss:     0.218     Train Acc:     94.22%      Val Acc:      91.8%
# 2022-11-15 11:10:03 INFO     [Epoch 258]   Loss:    0.2179     Train Acc:      94.3%      Val Acc:      91.8%
# 2022-11-15 11:10:03 INFO     [Epoch 259]   Loss:    0.2175     Train Acc:     94.24%      Val Acc:      91.6%
# 2022-11-15 11:10:03 INFO     [Epoch 260]   Loss:    0.2169     Train Acc:     94.36%      Val Acc:      91.7%
# 2022-11-15 11:10:03 INFO     [Epoch 261]   Loss:    0.2168     Train Acc:      94.3%      Val Acc:      91.7%
# 2022-11-15 11:10:03 INFO     [Epoch 262]   Loss:    0.2166     Train Acc:     94.38%      Val Acc:      91.8%
# 2022-11-15 11:10:03 INFO     [Epoch 263]   Loss:    0.2161     Train Acc:     94.28%      Val Acc:      91.9%
# 2022-11-15 11:10:03 INFO     [Epoch 264]   Loss:     0.216     Train Acc:     94.28%      Val Acc:      91.8%
# 2022-11-15 11:10:03 INFO     [Epoch 265]   Loss:    0.2154     Train Acc:     94.42%      Val Acc:      91.8%
# 2022-11-15 11:10:03 INFO     [Epoch 266]   Loss:    0.2146     Train Acc:     94.32%      Val Acc:      91.6%
# 2022-11-15 11:10:03 INFO     [Epoch 267]   Loss:    0.2148     Train Acc:     94.34%      Val Acc:      91.8%
# 2022-11-15 11:10:03 INFO     [Epoch 268]   Loss:    0.2143     Train Acc:     94.32%      Val Acc:      91.9%
# 2022-11-15 11:10:03 INFO     [Epoch 269]   Loss:    0.2141     Train Acc:     94.38%      Val Acc:      91.9%
# 2022-11-15 11:10:03 INFO     [Epoch 270]   Loss:    0.2137     Train Acc:     94.34%      Val Acc:      91.9%
# 2022-11-15 11:10:03 INFO     [Epoch 271]   Loss:    0.2131     Train Acc:     94.34%      Val Acc:      91.7%
# 2022-11-15 11:10:03 INFO     [Epoch 272]   Loss:    0.2126     Train Acc:     94.56%      Val Acc:      91.6%
# 2022-11-15 11:10:03 INFO     [Epoch 273]   Loss:    0.2125     Train Acc:      94.4%      Val Acc:      91.8%
# 2022-11-15 11:10:03 INFO     [Epoch 274]   Loss:    0.2119     Train Acc:     94.42%      Val Acc:      91.7%
# 2022-11-15 11:10:03 INFO     [Epoch 275]   Loss:    0.2118     Train Acc:     94.46%      Val Acc:      91.6%
# 2022-11-15 11:10:03 INFO     [Epoch 276]   Loss:    0.2116     Train Acc:     94.52%      Val Acc:      91.7%
# 2022-11-15 11:10:03 INFO     [Epoch 277]   Loss:    0.2113     Train Acc:      94.5%      Val Acc:      91.8%
# 2022-11-15 11:10:03 INFO     [Epoch 278]   Loss:    0.2108     Train Acc:     94.42%      Val Acc:      91.8%
# 2022-11-15 11:10:03 INFO     [Epoch 279]   Loss:    0.2109     Train Acc:      94.4%      Val Acc:      91.9%
# 2022-11-15 11:10:03 INFO     [Epoch 280]   Loss:      0.21     Train Acc:     94.48%      Val Acc:      91.8%
# 2022-11-15 11:10:03 INFO     [Epoch 281]   Loss:      0.21     Train Acc:     94.56%      Val Acc:      91.8%
# 2022-11-15 11:10:03 INFO     [Epoch 282]   Loss:    0.2095     Train Acc:     94.48%      Val Acc:      91.8%
# 2022-11-15 11:10:03 INFO     [Epoch 283]   Loss:     0.209     Train Acc:     94.52%      Val Acc:      91.8%
# 2022-11-15 11:10:03 INFO     [Epoch 284]   Loss:    0.2089     Train Acc:     94.56%      Val Acc:      91.6%
# 2022-11-15 11:10:03 INFO     [Epoch 285]   Loss:    0.2086     Train Acc:     94.62%      Val Acc:      91.8%
# 2022-11-15 11:10:03 INFO     [Epoch 286]   Loss:    0.2081     Train Acc:     94.74%      Val Acc:      91.8%
# 2022-11-15 11:10:04 INFO     [Epoch 287]   Loss:    0.2079     Train Acc:     94.62%      Val Acc:      91.9%
# 2022-11-15 11:10:04 INFO     [Epoch 288]   Loss:    0.2074     Train Acc:     94.56%      Val Acc:      92.1%
# 2022-11-15 11:10:04 INFO     [Epoch 289]   Loss:    0.2073     Train Acc:     94.72%      Val Acc:      91.9%
# 2022-11-15 11:10:04 INFO     [Epoch 290]   Loss:    0.2067     Train Acc:     94.62%      Val Acc:      91.8%
# 2022-11-15 11:10:04 INFO     [Epoch 291]   Loss:    0.2065     Train Acc:     94.66%      Val Acc:      91.7%
# 2022-11-15 11:10:04 INFO     [Epoch 292]   Loss:    0.2061     Train Acc:      94.6%      Val Acc:      91.9%
# 2022-11-15 11:10:04 INFO     [Epoch 293]   Loss:    0.2061     Train Acc:     94.84%      Val Acc:      92.0%
# 2022-11-15 11:10:04 INFO     [Epoch 294]   Loss:    0.2055     Train Acc:      94.7%      Val Acc:      91.7%
# 2022-11-15 11:10:04 INFO     [Epoch 295]   Loss:    0.2054     Train Acc:     94.78%      Val Acc:      91.9%
# 2022-11-15 11:10:04 INFO     [Epoch 296]   Loss:    0.2052     Train Acc:     94.66%      Val Acc:      91.8%
# 2022-11-15 11:10:04 INFO     [Epoch 297]   Loss:    0.2047     Train Acc:     94.54%      Val Acc:      91.9%
# 2022-11-15 11:10:04 INFO     [Epoch 298]   Loss:    0.2044     Train Acc:      94.7%      Val Acc:      91.8%
# 2022-11-15 11:10:04 INFO     [Epoch 299]   Loss:    0.2042     Train Acc:     94.66%      Val Acc:      91.8%
# 2022-11-15 11:10:04 INFO     [Epoch 300]   Loss:    0.2039     Train Acc:      94.7%      Val Acc:      91.9%
# 2022-11-15 11:10:04 INFO     [Epoch 301]   Loss:    0.2035     Train Acc:     94.74%      Val Acc:      91.9%
# 2022-11-15 11:10:04 INFO     [Epoch 302]   Loss:    0.2034     Train Acc:     94.74%      Val Acc:      91.9%
# 2022-11-15 11:10:04 INFO     [Epoch 303]   Loss:    0.2027     Train Acc:     94.54%      Val Acc:      91.8%
# 2022-11-15 11:10:04 INFO     [Epoch 304]   Loss:    0.2025     Train Acc:     94.72%      Val Acc:      91.9%
# 2022-11-15 11:10:04 INFO     [Epoch 305]   Loss:     0.202     Train Acc:     94.76%      Val Acc:      91.9%
# 2022-11-15 11:10:04 INFO     [Epoch 306]   Loss:     0.202     Train Acc:     94.76%      Val Acc:      92.0%
# 2022-11-15 11:10:04 INFO     [Epoch 307]   Loss:    0.2019     Train Acc:     94.74%      Val Acc:      91.9%
# 2022-11-15 11:10:04 INFO     [Epoch 308]   Loss:    0.2014     Train Acc:     94.86%      Val Acc:      91.8%
# 2022-11-15 11:10:04 INFO     [Epoch 309]   Loss:    0.2007     Train Acc:     94.84%      Val Acc:      91.8%
# 2022-11-15 11:10:04 INFO     [Epoch 310]   Loss:    0.2009     Train Acc:     94.76%      Val Acc:      91.9%
# 2022-11-15 11:10:04 INFO     [Epoch 311]   Loss:    0.2005     Train Acc:     94.74%      Val Acc:      91.9%
# 2022-11-15 11:10:04 INFO     [Epoch 312]   Loss:       0.2     Train Acc:      94.8%      Val Acc:      91.8%
# 2022-11-15 11:10:04 INFO     [Epoch 313]   Loss:    0.1996     Train Acc:     94.74%      Val Acc:      91.8%
# 2022-11-15 11:10:04 INFO     [Epoch 314]   Loss:    0.1993     Train Acc:     94.92%      Val Acc:      91.7%
# 2022-11-15 11:10:04 INFO     [Epoch 315]   Loss:    0.1993     Train Acc:      94.9%      Val Acc:      91.7%
# 2022-11-15 11:10:04 INFO     [Epoch 316]   Loss:    0.1988     Train Acc:     94.96%      Val Acc:      92.0%
# 2022-11-15 11:10:05 INFO     [Epoch 317]   Loss:    0.1986     Train Acc:     94.98%      Val Acc:      91.8%
# 2022-11-15 11:10:05 INFO     [Epoch 318]   Loss:    0.1986     Train Acc:     94.94%      Val Acc:      92.0%
# 2022-11-15 11:10:05 INFO     [Epoch 319]   Loss:    0.1978     Train Acc:     94.86%      Val Acc:      92.0%
# 2022-11-15 11:10:05 INFO     [Epoch 320]   Loss:    0.1978     Train Acc:     94.88%      Val Acc:      91.9%
# 2022-11-15 11:10:05 INFO     [Epoch 321]   Loss:    0.1976     Train Acc:     94.94%      Val Acc:      91.9%
# 2022-11-15 11:10:05 INFO     [Epoch 322]   Loss:    0.1972     Train Acc:     94.94%      Val Acc:      91.9%
# 2022-11-15 11:10:05 INFO     [Epoch 323]   Loss:    0.1969     Train Acc:     95.08%      Val Acc:      91.7%
# 2022-11-15 11:10:05 INFO     [Epoch 324]   Loss:    0.1968     Train Acc:     94.92%      Val Acc:      92.0%
# 2022-11-15 11:10:05 INFO     [Epoch 325]   Loss:    0.1961     Train Acc:     94.96%      Val Acc:      92.1%
# 2022-11-15 11:10:05 INFO     [Epoch 326]   Loss:    0.1956     Train Acc:     95.02%      Val Acc:      91.8%
# 2022-11-15 11:10:05 INFO     [Epoch 327]   Loss:    0.1958     Train Acc:     94.94%      Val Acc:      92.1%
# 2022-11-15 11:10:05 INFO     [Epoch 328]   Loss:    0.1954     Train Acc:      95.0%      Val Acc:      91.9%
# 2022-11-15 11:10:05 INFO     [Epoch 329]   Loss:     0.195     Train Acc:     94.98%      Val Acc:      91.9%
# 2022-11-15 11:10:05 INFO     [Epoch 330]   Loss:    0.1949     Train Acc:     94.92%      Val Acc:      91.9%
# 2022-11-15 11:10:05 INFO     [Epoch 331]   Loss:    0.1945     Train Acc:     94.98%      Val Acc:      91.9%
# 2022-11-15 11:10:05 INFO     [Epoch 332]   Loss:    0.1943     Train Acc:      95.1%      Val Acc:      91.9%
# 2022-11-15 11:10:05 INFO     [Epoch 333]   Loss:    0.1938     Train Acc:     95.14%      Val Acc:      91.9%
# 2022-11-15 11:10:05 INFO     [Epoch 334]   Loss:    0.1937     Train Acc:     94.98%      Val Acc:      91.9%
# 2022-11-15 11:10:05 INFO     [Epoch 335]   Loss:    0.1935     Train Acc:     94.92%      Val Acc:      91.8%
# 2022-11-15 11:10:05 INFO     [Epoch 336]   Loss:    0.1927     Train Acc:     95.08%      Val Acc:      91.8%
# 2022-11-15 11:10:05 INFO     [Epoch 337]   Loss:     0.193     Train Acc:     95.08%      Val Acc:      91.7%
# 2022-11-15 11:10:05 INFO     [Epoch 338]   Loss:    0.1927     Train Acc:     95.02%      Val Acc:      91.8%
# 2022-11-15 11:10:05 INFO     [Epoch 339]   Loss:    0.1923     Train Acc:     95.04%      Val Acc:      92.0%
# 2022-11-15 11:10:05 INFO     [Epoch 340]   Loss:    0.1921     Train Acc:      95.0%      Val Acc:      91.8%
# 2022-11-15 11:10:05 INFO     [Epoch 341]   Loss:    0.1914     Train Acc:     94.98%      Val Acc:      91.8%
# 2022-11-15 11:10:05 INFO     [Epoch 342]   Loss:    0.1914     Train Acc:     95.06%      Val Acc:      92.0%
# 2022-11-15 11:10:05 INFO     [Epoch 343]   Loss:    0.1911     Train Acc:     94.96%      Val Acc:      91.7%
# 2022-11-15 11:10:05 INFO     [Epoch 344]   Loss:    0.1911     Train Acc:      95.0%      Val Acc:      91.9%
# 2022-11-15 11:10:05 INFO     [Epoch 345]   Loss:    0.1906     Train Acc:      95.0%      Val Acc:      91.7%
# 2022-11-15 11:10:06 INFO     [Epoch 346]   Loss:    0.1902     Train Acc:      95.1%      Val Acc:      91.9%
# 2022-11-15 11:10:06 INFO     [Epoch 347]   Loss:      0.19     Train Acc:     95.04%      Val Acc:      91.8%
# 2022-11-15 11:10:06 INFO     [Epoch 348]   Loss:      0.19     Train Acc:      95.1%      Val Acc:      91.8%
# 2022-11-15 11:10:06 INFO     [Epoch 349]   Loss:    0.1894     Train Acc:     95.16%      Val Acc:      91.8%
# 2022-11-15 11:10:06 INFO     [Epoch 350]   Loss:    0.1896     Train Acc:     95.02%      Val Acc:      91.7%
# 2022-11-15 11:10:06 INFO     [Epoch 351]   Loss:    0.1892     Train Acc:      95.1%      Val Acc:      91.9%
# 2022-11-15 11:10:06 INFO     [Epoch 352]   Loss:    0.1887     Train Acc:     95.06%      Val Acc:      91.8%
# 2022-11-15 11:10:06 INFO     [Epoch 353]   Loss:    0.1889     Train Acc:     95.06%      Val Acc:      91.6%
# 2022-11-15 11:10:06 INFO     [Epoch 354]   Loss:    0.1884     Train Acc:     95.02%      Val Acc:      91.6%
# 2022-11-15 11:10:06 INFO     [Epoch 355]   Loss:    0.1879     Train Acc:      95.1%      Val Acc:      91.9%
# 2022-11-15 11:10:06 INFO     [Epoch 356]   Loss:    0.1877     Train Acc:     95.14%      Val Acc:      92.0%
# 2022-11-15 11:10:06 INFO     [Epoch 357]   Loss:    0.1874     Train Acc:     95.14%      Val Acc:      91.7%
# 2022-11-15 11:10:06 INFO     [Epoch 358]   Loss:    0.1871     Train Acc:     95.22%      Val Acc:      91.8%
# 2022-11-15 11:10:06 INFO     [Epoch 359]   Loss:    0.1869     Train Acc:     95.06%      Val Acc:      91.8%
# 2022-11-15 11:10:06 INFO     [Epoch 360]   Loss:    0.1866     Train Acc:     95.18%      Val Acc:      92.0%
# 2022-11-15 11:10:06 INFO     [Epoch 361]   Loss:    0.1865     Train Acc:     95.06%      Val Acc:      91.7%
# 2022-11-15 11:10:06 INFO     [Epoch 362]   Loss:    0.1863     Train Acc:      95.1%      Val Acc:      91.9%
# 2022-11-15 11:10:06 INFO     [Epoch 363]   Loss:    0.1861     Train Acc:      95.2%      Val Acc:      91.8%
# 2022-11-15 11:10:06 INFO     [Epoch 364]   Loss:    0.1857     Train Acc:     95.18%      Val Acc:      91.8%
# 2022-11-15 11:10:06 INFO     [Epoch 365]   Loss:    0.1854     Train Acc:     95.22%      Val Acc:      91.8%
# 2022-11-15 11:10:06 INFO     [Epoch 366]   Loss:    0.1853     Train Acc:     95.16%      Val Acc:      91.8%
# 2022-11-15 11:10:06 INFO     [Epoch 367]   Loss:    0.1854     Train Acc:     95.22%      Val Acc:      91.8%
# 2022-11-15 11:10:06 INFO     [Epoch 368]   Loss:    0.1848     Train Acc:     95.16%      Val Acc:      91.9%
# 2022-11-15 11:10:06 INFO     [Epoch 369]   Loss:    0.1844     Train Acc:     95.26%      Val Acc:      91.6%
# 2022-11-15 11:10:06 INFO     [Epoch 370]   Loss:    0.1842     Train Acc:     95.18%      Val Acc:      91.8%
# 2022-11-15 11:10:06 INFO     [Epoch 371]   Loss:    0.1838     Train Acc:     95.14%      Val Acc:      92.1%
# 2022-11-15 11:10:06 INFO     [Epoch 372]   Loss:    0.1837     Train Acc:     95.26%      Val Acc:      91.7%
# 2022-11-15 11:10:06 INFO     [Epoch 373]   Loss:    0.1835     Train Acc:     95.14%      Val Acc:      92.1%
# 2022-11-15 11:10:06 INFO     [Epoch 374]   Loss:    0.1831     Train Acc:     95.18%      Val Acc:      91.9%
# 2022-11-15 11:10:07 INFO     [Epoch 375]   Loss:     0.183     Train Acc:     95.22%      Val Acc:      92.0%
# 2022-11-15 11:10:07 INFO     [Epoch 376]   Loss:    0.1826     Train Acc:      95.3%      Val Acc:      91.8%
# 2022-11-15 11:10:07 INFO     [Epoch 377]   Loss:    0.1826     Train Acc:     95.18%      Val Acc:      91.8%
# 2022-11-15 11:10:07 INFO     [Epoch 378]   Loss:    0.1824     Train Acc:     95.26%      Val Acc:      91.8%
# 2022-11-15 11:10:07 INFO     [Epoch 379]   Loss:    0.1819     Train Acc:     95.24%      Val Acc:      91.9%
# 2022-11-15 11:10:07 INFO     [Epoch 380]   Loss:    0.1815     Train Acc:     95.34%      Val Acc:      92.0%
# 2022-11-15 11:10:07 INFO     [Epoch 381]   Loss:    0.1817     Train Acc:      95.3%      Val Acc:      91.9%
# 2022-11-15 11:10:07 INFO     [Epoch 382]   Loss:    0.1812     Train Acc:     95.28%      Val Acc:      92.2%
# 2022-11-15 11:10:07 INFO     [Epoch 383]   Loss:    0.1809     Train Acc:     95.26%      Val Acc:      91.8%
# 2022-11-15 11:10:07 INFO     [Epoch 384]   Loss:    0.1808     Train Acc:     95.24%      Val Acc:      92.0%
# 2022-11-15 11:10:07 INFO     [Epoch 385]   Loss:    0.1801     Train Acc:     95.36%      Val Acc:      91.9%
# 2022-11-15 11:10:07 INFO     [Epoch 386]   Loss:    0.1802     Train Acc:     95.28%      Val Acc:      92.0%
# 2022-11-15 11:10:07 INFO     [Epoch 387]   Loss:    0.1799     Train Acc:     95.34%      Val Acc:      91.6%
# 2022-11-15 11:10:07 INFO     [Epoch 388]   Loss:    0.1797     Train Acc:      95.4%      Val Acc:      91.8%
# 2022-11-15 11:10:07 INFO     [Epoch 389]   Loss:    0.1794     Train Acc:     95.26%      Val Acc:      91.6%
# 2022-11-15 11:10:07 INFO     [Epoch 390]   Loss:    0.1793     Train Acc:     95.36%      Val Acc:      92.0%
# 2022-11-15 11:10:07 INFO     [Epoch 391]   Loss:     0.179     Train Acc:     95.28%      Val Acc:      91.9%
# 2022-11-15 11:10:07 INFO     [Epoch 392]   Loss:    0.1787     Train Acc:     95.26%      Val Acc:      92.2%
# 2022-11-15 11:10:07 INFO     [Epoch 393]   Loss:    0.1784     Train Acc:     95.26%      Val Acc:      92.0%
# 2022-11-15 11:10:07 INFO     [Epoch 394]   Loss:    0.1783     Train Acc:     95.38%      Val Acc:      91.8%
# 2022-11-15 11:10:07 INFO     [Epoch 395]   Loss:    0.1778     Train Acc:     95.28%      Val Acc:      91.8%
# 2022-11-15 11:10:07 INFO     [Epoch 396]   Loss:    0.1778     Train Acc:     95.28%      Val Acc:      92.0%
# 2022-11-15 11:10:07 INFO     [Epoch 397]   Loss:    0.1778     Train Acc:     95.32%      Val Acc:      92.3%
# 2022-11-15 11:10:07 INFO     [Epoch 398]   Loss:    0.1773     Train Acc:     95.42%      Val Acc:      92.1%
# 2022-11-15 11:10:07 INFO     [Epoch 399]   Loss:    0.1769     Train Acc:     95.44%      Val Acc:      92.0%
# 2022-11-15 11:10:07 INFO     [Epoch 400]   Loss:    0.1768     Train Acc:     95.42%      Val Acc:      92.0%
# 2022-11-15 11:10:07 INFO     [Epoch 401]   Loss:    0.1768     Train Acc:     95.38%      Val Acc:      92.0%
# 2022-11-15 11:10:07 INFO     [Epoch 402]   Loss:    0.1763     Train Acc:     95.36%      Val Acc:      92.1%
# 2022-11-15 11:10:07 INFO     [Epoch 403]   Loss:    0.1761     Train Acc:     95.32%      Val Acc:      92.1%
# 2022-11-15 11:10:08 INFO     [Epoch 404]   Loss:    0.1758     Train Acc:     95.34%      Val Acc:      91.9%
# 2022-11-15 11:10:08 INFO     [Epoch 405]   Loss:    0.1759     Train Acc:      95.3%      Val Acc:      92.2%
# 2022-11-15 11:10:08 INFO     [Epoch 406]   Loss:    0.1755     Train Acc:     95.38%      Val Acc:      92.1%
# 2022-11-15 11:10:08 INFO     [Epoch 407]   Loss:    0.1747     Train Acc:     95.48%      Val Acc:      92.0%
# 2022-11-15 11:10:08 INFO     [Epoch 408]   Loss:    0.1753     Train Acc:     95.34%      Val Acc:      92.0%
# 2022-11-15 11:10:08 INFO     [Epoch 409]   Loss:    0.1748     Train Acc:     95.46%      Val Acc:      91.9%
# 2022-11-15 11:10:08 INFO     [Epoch 410]   Loss:    0.1745     Train Acc:     95.44%      Val Acc:      92.0%
# 2022-11-15 11:10:08 INFO     [Epoch 411]   Loss:    0.1744     Train Acc:      95.4%      Val Acc:      92.1%
# ...
# 2022-11-15 11:10:59 INFO     [Epoch 1856]   Loss:   0.03761     Train Acc:     99.64%      Val Acc:      92.1%
# 2022-11-15 11:10:59 INFO     [Epoch 1857]   Loss:   0.03759     Train Acc:     99.58%      Val Acc:      92.0%
# 2022-11-15 11:10:59 INFO     [Epoch 1858]   Loss:   0.03767     Train Acc:     99.64%      Val Acc:      92.1%
# 2022-11-15 11:10:59 INFO     [Epoch 1859]   Loss:   0.03755     Train Acc:     99.62%      Val Acc:      92.0%
# 2022-11-15 11:10:59 INFO     [Epoch 1860]   Loss:   0.03747     Train Acc:     99.58%      Val Acc:      92.0%
# 2022-11-15 11:10:59 INFO     [Epoch 1861]   Loss:   0.03756     Train Acc:      99.6%      Val Acc:      92.3%
# 2022-11-15 11:10:59 INFO     [Epoch 1862]   Loss:   0.03752     Train Acc:     99.64%      Val Acc:      92.1%
# 2022-11-15 11:10:59 INFO     [Epoch 1863]   Loss:   0.03743     Train Acc:     99.62%      Val Acc:      92.4%
# 2022-11-15 11:10:59 INFO     [Epoch 1864]   Loss:   0.03739     Train Acc:      99.6%      Val Acc:      92.5%
# 2022-11-15 11:10:59 INFO     [Epoch 1865]   Loss:   0.03731     Train Acc:     99.64%      Val Acc:      92.1%
# 2022-11-15 11:10:59 INFO     [Epoch 1866]   Loss:    0.0374     Train Acc:      99.6%      Val Acc:      92.0%
# 2022-11-15 11:10:59 INFO     [Epoch 1867]   Loss:   0.03734     Train Acc:     99.62%      Val Acc:      92.1%
# 2022-11-15 11:10:59 INFO     [Epoch 1868]   Loss:   0.03727     Train Acc:     99.56%      Val Acc:      92.1%
# 2022-11-15 11:10:59 INFO     [Epoch 1869]   Loss:   0.03719     Train Acc:     99.66%      Val Acc:      92.1%
# 2022-11-15 11:10:59 INFO     [Epoch 1870]   Loss:   0.03711     Train Acc:     99.62%      Val Acc:      92.0%
# 2022-11-15 11:10:59 INFO     [Epoch 1871]   Loss:   0.03718     Train Acc:     99.62%      Val Acc:      92.0%
# 2022-11-15 11:10:59 INFO     [Epoch 1872]   Loss:   0.03709     Train Acc:     99.62%      Val Acc:      92.0%
# 2022-11-15 11:10:59 INFO     [Epoch 1873]   Loss:   0.03711     Train Acc:      99.6%      Val Acc:      92.2%
# 2022-11-15 11:10:59 INFO     [Epoch 1874]   Loss:   0.03703     Train Acc:     99.62%      Val Acc:      92.2%
# 2022-11-15 11:10:59 INFO     [Epoch 1875]   Loss:   0.03711     Train Acc:     99.62%      Val Acc:      92.0%
# 2022-11-15 11:10:59 INFO     [Epoch 1876]   Loss:   0.03701     Train Acc:      99.6%      Val Acc:      92.1%
# 2022-11-15 11:10:59 INFO     [Epoch 1877]   Loss:   0.03697     Train Acc:     99.62%      Val Acc:      92.2%
# 2022-11-15 11:10:59 INFO     [Epoch 1878]   Loss:   0.03688     Train Acc:      99.6%      Val Acc:      92.1%
# 2022-11-15 11:10:59 INFO     [Epoch 1879]   Loss:    0.0369     Train Acc:     99.64%      Val Acc:      92.1%
# 2022-11-15 11:11:00 INFO     [Epoch 1880]   Loss:   0.03681     Train Acc:     99.66%      Val Acc:      92.0%
# 2022-11-15 11:11:00 INFO     [Epoch 1881]   Loss:   0.03688     Train Acc:     99.62%      Val Acc:      92.2%
# 2022-11-15 11:11:00 INFO     [Epoch 1882]   Loss:   0.03678     Train Acc:     99.66%      Val Acc:      92.3%
# 2022-11-15 11:11:00 INFO     [Epoch 1883]   Loss:   0.03673     Train Acc:      99.6%      Val Acc:      92.3%
# 2022-11-15 11:11:00 INFO     [Epoch 1884]   Loss:   0.03661     Train Acc:     99.66%      Val Acc:      92.0%
# 2022-11-15 11:11:00 INFO     [Epoch 1885]   Loss:   0.03671     Train Acc:     99.64%      Val Acc:      92.1%
# 2022-11-15 11:11:00 INFO     [Epoch 1886]   Loss:   0.03669     Train Acc:      99.6%      Val Acc:      92.1%
# 2022-11-15 11:11:00 INFO     [Epoch 1887]   Loss:   0.03661     Train Acc:     99.64%      Val Acc:      92.1%
# 2022-11-15 11:11:00 INFO     [Epoch 1888]   Loss:   0.03662     Train Acc:     99.62%      Val Acc:      91.9%
# 2022-11-15 11:11:00 INFO     [Epoch 1889]   Loss:   0.03657     Train Acc:     99.58%      Val Acc:      92.1%
# 2022-11-15 11:11:00 INFO     [Epoch 1890]   Loss:   0.03659     Train Acc:     99.62%      Val Acc:      91.9%
# 2022-11-15 11:11:00 INFO     [Epoch 1891]   Loss:   0.03643     Train Acc:     99.64%      Val Acc:      92.4%
# 2022-11-15 11:11:00 INFO     [Epoch 1892]   Loss:   0.03649     Train Acc:     99.66%      Val Acc:      92.2%
# 2022-11-15 11:11:00 INFO     [Epoch 1893]   Loss:   0.03645     Train Acc:     99.64%      Val Acc:      92.1%
# 2022-11-15 11:11:00 INFO     [Epoch 1894]   Loss:   0.03634     Train Acc:     99.62%      Val Acc:      92.4%
# 2022-11-15 11:11:00 INFO     [Epoch 1895]   Loss:   0.03633     Train Acc:     99.64%      Val Acc:      92.1%
# 2022-11-15 11:11:00 INFO     [Epoch 1896]   Loss:    0.0363     Train Acc:      99.6%      Val Acc:      92.0%
# 2022-11-15 11:11:00 INFO     [Epoch 1897]   Loss:   0.03632     Train Acc:     99.64%      Val Acc:      92.3%
# 2022-11-15 11:11:00 INFO     [Epoch 1898]   Loss:   0.03626     Train Acc:     99.64%      Val Acc:      92.3%
# 2022-11-15 11:11:00 INFO     [Epoch 1899]   Loss:   0.03624     Train Acc:     99.64%      Val Acc:      92.3%
# 2022-11-15 11:11:00 INFO     [Epoch 1900]   Loss:   0.03616     Train Acc:     99.64%      Val Acc:      92.0%
# 2022-11-15 11:11:00 INFO     [Epoch 1901]   Loss:   0.03619     Train Acc:     99.62%      Val Acc:      92.3%
# 2022-11-15 11:11:00 INFO     [Epoch 1902]   Loss:   0.03619     Train Acc:     99.68%      Val Acc:      92.0%
# 2022-11-15 11:11:00 INFO     [Epoch 1903]   Loss:   0.03608     Train Acc:     99.64%      Val Acc:      92.1%
# 2022-11-15 11:11:00 INFO     [Epoch 1904]   Loss:   0.03597     Train Acc:     99.66%      Val Acc:      91.9%
# 2022-11-15 11:11:00 INFO     [Epoch 1905]   Loss:     0.036     Train Acc:     99.62%      Val Acc:      92.2%
# 2022-11-15 11:11:00 INFO     [Epoch 1906]   Loss:   0.03594     Train Acc:     99.64%      Val Acc:      92.0%
# 2022-11-15 11:11:01 INFO     [Epoch 1907]   Loss:   0.03605     Train Acc:     99.62%      Val Acc:      92.0%
# 2022-11-15 11:11:01 INFO     [Epoch 1908]   Loss:   0.03593     Train Acc:     99.62%      Val Acc:      92.3%
# 2022-11-15 11:11:01 INFO     [Epoch 1909]   Loss:   0.03593     Train Acc:     99.64%      Val Acc:      92.3%
# 2022-11-15 11:11:01 INFO     [Epoch 1910]   Loss:   0.03574     Train Acc:     99.66%      Val Acc:      92.0%
# 2022-11-15 11:11:01 INFO     [Epoch 1911]   Loss:   0.03581     Train Acc:     99.64%      Val Acc:      92.0%
# 2022-11-15 11:11:01 INFO     [Epoch 1912]   Loss:   0.03581     Train Acc:     99.64%      Val Acc:      92.0%
# 2022-11-15 11:11:01 INFO     [Epoch 1913]   Loss:   0.03569     Train Acc:     99.66%      Val Acc:      91.8%
# 2022-11-15 11:11:01 INFO     [Epoch 1914]   Loss:   0.03573     Train Acc:     99.64%      Val Acc:      92.2%
# 2022-11-15 11:11:01 INFO     [Epoch 1915]   Loss:   0.03561     Train Acc:     99.68%      Val Acc:      92.1%
# 2022-11-15 11:11:01 INFO     [Epoch 1916]   Loss:   0.03561     Train Acc:     99.66%      Val Acc:      92.3%
# 2022-11-15 11:11:01 INFO     [Epoch 1917]   Loss:   0.03567     Train Acc:     99.64%      Val Acc:      92.1%
# 2022-11-15 11:11:01 INFO     [Epoch 1918]   Loss:   0.03564     Train Acc:     99.66%      Val Acc:      92.1%
# 2022-11-15 11:11:01 INFO     [Epoch 1919]   Loss:   0.03551     Train Acc:     99.66%      Val Acc:      91.9%
# 2022-11-15 11:11:01 INFO     [Epoch 1920]   Loss:   0.03549     Train Acc:     99.64%      Val Acc:      91.9%
# 2022-11-15 11:11:01 INFO     [Epoch 1921]   Loss:   0.03554     Train Acc:     99.62%      Val Acc:      92.1%
# 2022-11-15 11:11:01 INFO     [Epoch 1922]   Loss:    0.0354     Train Acc:     99.66%      Val Acc:      92.2%
# 2022-11-15 11:11:01 INFO     [Epoch 1923]   Loss:   0.03542     Train Acc:      99.6%      Val Acc:      92.0%
# 2022-11-15 11:11:01 INFO     [Epoch 1924]   Loss:   0.03542     Train Acc:     99.68%      Val Acc:      92.0%
# 2022-11-15 11:11:01 INFO     [Epoch 1925]   Loss:   0.03541     Train Acc:     99.66%      Val Acc:      91.9%
# 2022-11-15 11:11:01 INFO     [Epoch 1926]   Loss:   0.03528     Train Acc:     99.66%      Val Acc:      92.4%
# 2022-11-15 11:11:01 INFO     [Epoch 1927]   Loss:   0.03545     Train Acc:     99.68%      Val Acc:      92.0%
# 2022-11-15 11:11:01 INFO     [Epoch 1928]   Loss:   0.03525     Train Acc:     99.64%      Val Acc:      92.0%
# 2022-11-15 11:11:01 INFO     [Epoch 1929]   Loss:   0.03518     Train Acc:     99.64%      Val Acc:      92.3%
# 2022-11-15 11:11:01 INFO     [Epoch 1930]   Loss:   0.03521     Train Acc:     99.68%      Val Acc:      92.2%
# 2022-11-15 11:11:01 INFO     [Epoch 1931]   Loss:   0.03519     Train Acc:     99.64%      Val Acc:      92.4%
# 2022-11-15 11:11:01 INFO     [Epoch 1932]   Loss:   0.03516     Train Acc:     99.68%      Val Acc:      92.3%
# 2022-11-15 11:11:01 INFO     [Epoch 1933]   Loss:   0.03518     Train Acc:     99.68%      Val Acc:      92.2%
# 2022-11-15 11:11:01 INFO     [Epoch 1934]   Loss:   0.03503     Train Acc:     99.66%      Val Acc:      92.1%
# 2022-11-15 11:11:02 INFO     [Epoch 1935]   Loss:   0.03509     Train Acc:     99.68%      Val Acc:      92.3%
# 2022-11-15 11:11:02 INFO     [Epoch 1936]   Loss:   0.03499     Train Acc:     99.66%      Val Acc:      92.4%
# 2022-11-15 11:11:02 INFO     [Epoch 1937]   Loss:   0.03506     Train Acc:     99.64%      Val Acc:      92.2%
# 2022-11-15 11:11:02 INFO     [Epoch 1938]   Loss:   0.03493     Train Acc:     99.66%      Val Acc:      92.0%
# 2022-11-15 11:11:02 INFO     [Epoch 1939]   Loss:   0.03485     Train Acc:     99.66%      Val Acc:      92.4%
# 2022-11-15 11:11:02 INFO     [Epoch 1940]   Loss:   0.03487     Train Acc:     99.68%      Val Acc:      92.4%
# 2022-11-15 11:11:02 INFO     [Epoch 1941]   Loss:   0.03479     Train Acc:     99.68%      Val Acc:      92.0%
# 2022-11-15 11:11:02 INFO     [Epoch 1942]   Loss:   0.03489     Train Acc:     99.62%      Val Acc:      92.2%
# 2022-11-15 11:11:02 INFO     [Epoch 1943]   Loss:    0.0348     Train Acc:     99.66%      Val Acc:      92.2%
# 2022-11-15 11:11:02 INFO     [Epoch 1944]   Loss:   0.03478     Train Acc:     99.66%      Val Acc:      92.3%
# 2022-11-15 11:11:02 INFO     [Epoch 1945]   Loss:   0.03472     Train Acc:     99.66%      Val Acc:      92.5%
# 2022-11-15 11:11:02 INFO     [Epoch 1946]   Loss:    0.0347     Train Acc:     99.68%      Val Acc:      92.1%
# 2022-11-15 11:11:02 INFO     [Epoch 1947]   Loss:   0.03469     Train Acc:     99.68%      Val Acc:      92.0%
# 2022-11-15 11:11:02 INFO     [Epoch 1948]   Loss:   0.03459     Train Acc:     99.66%      Val Acc:      92.3%
# 2022-11-15 11:11:02 INFO     [Epoch 1949]   Loss:   0.03463     Train Acc:     99.66%      Val Acc:      92.1%
# 2022-11-15 11:11:02 INFO     [Epoch 1950]   Loss:   0.03455     Train Acc:     99.66%      Val Acc:      92.2%
# 2022-11-15 11:11:02 INFO     [Epoch 1951]   Loss:   0.03451     Train Acc:     99.68%      Val Acc:      92.1%
# 2022-11-15 11:11:02 INFO     [Epoch 1952]   Loss:   0.03447     Train Acc:     99.68%      Val Acc:      92.4%
# 2022-11-15 11:11:02 INFO     [Epoch 1953]   Loss:   0.03454     Train Acc:     99.66%      Val Acc:      92.2%
# 2022-11-15 11:11:02 INFO     [Epoch 1954]   Loss:   0.03437     Train Acc:     99.66%      Val Acc:      92.4%
# 2022-11-15 11:11:02 INFO     [Epoch 1955]   Loss:   0.03437     Train Acc:     99.64%      Val Acc:      92.1%
# 2022-11-15 11:11:02 INFO     [Epoch 1956]   Loss:   0.03434     Train Acc:      99.7%      Val Acc:      92.1%
# 2022-11-15 11:11:02 INFO     [Epoch 1957]   Loss:   0.03433     Train Acc:     99.68%      Val Acc:      92.1%
# 2022-11-15 11:11:02 INFO     [Epoch 1958]   Loss:   0.03435     Train Acc:     99.68%      Val Acc:      91.9%
# 2022-11-15 11:11:02 INFO     [Epoch 1959]   Loss:   0.03432     Train Acc:     99.64%      Val Acc:      92.1%
# 2022-11-15 11:11:02 INFO     [Epoch 1960]   Loss:   0.03424     Train Acc:      99.7%      Val Acc:      92.0%
# 2022-11-15 11:11:02 INFO     [Epoch 1961]   Loss:   0.03423     Train Acc:     99.66%      Val Acc:      92.3%
# 2022-11-15 11:11:02 INFO     [Epoch 1962]   Loss:   0.03435     Train Acc:     99.66%      Val Acc:      92.0%
# 2022-11-15 11:11:02 INFO     [Epoch 1963]   Loss:   0.03422     Train Acc:     99.64%      Val Acc:      92.4%
# 2022-11-15 11:11:02 INFO     [Epoch 1964]   Loss:   0.03421     Train Acc:     99.68%      Val Acc:      92.5%
# 2022-11-15 11:11:03 INFO     [Epoch 1965]   Loss:   0.03415     Train Acc:      99.7%      Val Acc:      92.2%
# 2022-11-15 11:11:03 INFO     [Epoch 1966]   Loss:   0.03412     Train Acc:     99.68%      Val Acc:      92.1%
# 2022-11-15 11:11:03 INFO     [Epoch 1967]   Loss:   0.03399     Train Acc:     99.66%      Val Acc:      92.4%
# 2022-11-15 11:11:03 INFO     [Epoch 1968]   Loss:   0.03411     Train Acc:     99.64%      Val Acc:      92.1%
# 2022-11-15 11:11:03 INFO     [Epoch 1969]   Loss:   0.03407     Train Acc:     99.66%      Val Acc:      92.1%
# 2022-11-15 11:11:03 INFO     [Epoch 1970]   Loss:   0.03389     Train Acc:     99.68%      Val Acc:      92.2%
# 2022-11-15 11:11:03 INFO     [Epoch 1971]   Loss:    0.0339     Train Acc:      99.7%      Val Acc:      92.0%
# 2022-11-15 11:11:03 INFO     [Epoch 1972]   Loss:   0.03389     Train Acc:     99.68%      Val Acc:      92.0%
# 2022-11-15 11:11:03 INFO     [Epoch 1973]   Loss:   0.03388     Train Acc:     99.68%      Val Acc:      92.6%
# 2022-11-15 11:11:03 INFO     [Epoch 1974]   Loss:   0.03381     Train Acc:     99.66%      Val Acc:      92.0%
# 2022-11-15 11:11:03 INFO     [Epoch 1975]   Loss:   0.03378     Train Acc:     99.68%      Val Acc:      92.0%
# 2022-11-15 11:11:03 INFO     [Epoch 1976]   Loss:   0.03375     Train Acc:     99.68%      Val Acc:      92.1%
# 2022-11-15 11:11:03 INFO     [Epoch 1977]   Loss:   0.03369     Train Acc:     99.68%      Val Acc:      92.1%
# 2022-11-15 11:11:03 INFO     [Epoch 1978]   Loss:   0.03371     Train Acc:     99.68%      Val Acc:      92.1%
# 2022-11-15 11:11:03 INFO     [Epoch 1979]   Loss:   0.03358     Train Acc:     99.68%      Val Acc:      92.4%
# 2022-11-15 11:11:03 INFO     [Epoch 1980]   Loss:   0.03373     Train Acc:      99.7%      Val Acc:      92.3%
# 2022-11-15 11:11:03 INFO     [Epoch 1981]   Loss:   0.03364     Train Acc:     99.68%      Val Acc:      92.6%
# 2022-11-15 11:11:03 INFO     [Epoch 1982]   Loss:   0.03364     Train Acc:     99.66%      Val Acc:      92.1%
# 2022-11-15 11:11:03 INFO     [Epoch 1983]   Loss:   0.03358     Train Acc:      99.7%      Val Acc:      91.9%
# 2022-11-15 11:11:03 INFO     [Epoch 1984]   Loss:    0.0335     Train Acc:     99.66%      Val Acc:      91.9%
# 2022-11-15 11:11:03 INFO     [Epoch 1985]   Loss:    0.0335     Train Acc:     99.72%      Val Acc:      91.9%
# 2022-11-15 11:11:03 INFO     [Epoch 1986]   Loss:   0.03351     Train Acc:     99.68%      Val Acc:      92.3%
# 2022-11-15 11:11:03 INFO     [Epoch 1987]   Loss:   0.03337     Train Acc:     99.66%      Val Acc:      92.1%
# 2022-11-15 11:11:03 INFO     [Epoch 1988]   Loss:    0.0334     Train Acc:      99.7%      Val Acc:      92.2%
# 2022-11-15 11:11:03 INFO     [Epoch 1989]   Loss:   0.03337     Train Acc:     99.66%      Val Acc:      92.1%
# 2022-11-15 11:11:03 INFO     [Epoch 1990]   Loss:   0.03339     Train Acc:     99.66%      Val Acc:      92.0%
# 2022-11-15 11:11:04 INFO     [Epoch 1991]   Loss:   0.03336     Train Acc:     99.66%      Val Acc:      92.2%
# 2022-11-15 11:11:04 INFO     [Epoch 1992]   Loss:   0.03326     Train Acc:     99.72%      Val Acc:      91.9%
# 2022-11-15 11:11:04 INFO     [Epoch 1993]   Loss:   0.03334     Train Acc:      99.7%      Val Acc:      92.1%
# 2022-11-15 11:11:04 INFO     [Epoch 1994]   Loss:   0.03321     Train Acc:      99.7%      Val Acc:      92.2%
# 2022-11-15 11:11:04 INFO     [Epoch 1995]   Loss:   0.03326     Train Acc:      99.7%      Val Acc:      92.1%
# 2022-11-15 11:11:04 INFO     [Epoch 1996]   Loss:   0.03315     Train Acc:     99.68%      Val Acc:      92.1%
# 2022-11-15 11:11:04 INFO     [Epoch 1997]   Loss:   0.03308     Train Acc:     99.68%      Val Acc:      92.2%
# 2022-11-15 11:11:04 INFO     [Epoch 1998]   Loss:   0.03313     Train Acc:      99.7%      Val Acc:      92.5%
# 2022-11-15 11:11:04 INFO     [Epoch 1999]   Loss:   0.03305     Train Acc:     99.66%      Val Acc:      92.5%

# %%
import numpy as np

import matplotlib.pyplot as plt
import logging
logging.basicConfig(
    format='%(asctime)s %(levelname)-8s %(message)s',
    level=logging.INFO,
    datefmt='%Y-%m-%d %H:%M:%S')
import matplotlib
font = {'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)


# GLOBAL PARAMETERS FOR STOCHASTIC GRADIENT DESCENT
np.random.seed(1000)
step_size = 0.01
batch_size = 200
max_epochs = 2000

# GLOBAL PARAMETERS FOR NETWORK ARCHITECTURE
number_of_layers = 2
width_of_layers = 16  # only matters if number of layers > 1
activation = "ReLU" if False else "Sigmoid" 

def main():

  # Load data and display an example
  X_train, Y_train, X_val, Y_val, X_test = loadData()
  displayExample(X_train[np.random.randint(0,len(X_train))])


  # Build a network with input feature dimensions, output feature dimension,
  # hidden dimension, and number of layers as specified below
  net = FeedForwardNeuralNetwork(X_train.shape[1],10,width_of_layers,number_of_layers, activation=activation)

  # Some lists for book-keeping for plotting later
  losses = []
  val_losses = []
  accs = []
  val_accs = []


  # Loss function
  lossFunc = CrossEntropySoftmax()

  # Indicies we will use to shuffle data randomly
  inds = np.arange(len(X_train))
  for i in range(max_epochs):
    
    # Shuffled indicies so we go through data in new random batches
    np.random.shuffle(inds)

    # Go through all datapoints once (aka an epoch)
    j = 0
    acc_running = loss_running = 0
    while j < len(X_train):

      # Select the members of this random batch
      b = min(batch_size, len(X_train)-j)
      X_batch = X_train[inds[j:j+b]]
      Y_batch = Y_train[inds[j:j+b]].astype(np.int)
    
      # Compute the scores for our 10 classes using our model
      logits = net.forward(X_batch)
      loss = lossFunc.forward(logits, Y_batch)
      acc = np.mean( np.argmax(logits,axis=1)[:,np.newaxis] == Y_batch)
      
      # Compute gradient of Cross-Entropy Loss with respect to logits
      loss_grad = lossFunc.backward()

      # Pass gradient back through networks
      net.backward(loss_grad)

      # Take a step of gradient descent
      net.step(step_size)

      #Record losses and accuracy then move to next batch
      losses.append(loss)
      accs.append(acc)
      loss_running += loss*b
      acc_running += acc*b

      j+=batch_size

    # Evaluate performance on validation. This function looks very similar to the training loop above,
    vloss, vacc = evaluateValidation(net, X_val, Y_val, batch_size)
    val_losses.append(vloss)
    val_accs.append(vacc)
    
    # Print out the average stats over this epoch
    logging.info("[Epoch {:3}]   Loss:  {:8.4}     Train Acc:  {:8.4}%      Val Acc:  {:8.4}%".format(i,loss_running/len(X_train), acc_running / len(X_train)*100,vacc*100))

    


  fig, ax1 = plt.subplots(figsize=(16,9))
  color = 'tab:red'
  ax1.plot(range(len(losses)), losses, c=color, alpha=0.25, label="Train Loss")
  ax1.plot([np.ceil((i+1)*len(X_train)/batch_size) for i in range(len(val_losses))], val_losses,c="red", label="Val. Loss")
  ax1.set_xlabel("Iterations")
  ax1.set_ylabel("Avg. Cross-Entropy Loss", c=color)
  ax1.tick_params(axis='y', labelcolor=color)
  ax1.set_ylim(-0.01,3)

  ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

  color = 'tab:blue'
  ax2.plot(range(len(losses)), accs, c=color, label="Train Acc.", alpha=0.25)
  ax2.plot([np.ceil((i+1)*len(X_train)/batch_size) for i in range(len(val_accs))], val_accs,c="blue", label="Val. Acc.")
  ax2.set_ylabel(" Accuracy", c=color)
  ax2.tick_params(axis='y', labelcolor=color)
  ax2.set_ylim(-0.01,1.01)

  fig.tight_layout()  # otherwise the right y-label is slightly clipped
  ax1.legend(loc="center")
  ax2.legend(loc="center right")
  plt.show()


  ################################
  # Q7 Evaluate on Test
  ################################
  x_size = len(X_test)
  rowN = np.arange(0,x_size)
  rowN = rowN[:,None]
  test_out = np.argmax(net.forward(X_test), axis=1)[:,np.newaxis]
  test_final = np.hstack((rowN, test_out))
  np.savetxt("test_prediction_hw3.csv", test_final, header="id,digit", fmt='%i', comments='', delimiter=",")


class LinearLayer:

  # Initialize our layer with (input_dim, output_dim) weight matrix and a (1,output_dim) bias vector
  def __init__(self, input_dim, output_dim):
    self.weights = np.random.randn(input_dim, output_dim)* np.sqrt(2. / input_dim)
    self.bias = np.ones( (1,output_dim) )*0.5

  # During the forward pass, we simply compute Xw+b
  def forward(self, input):
    self.input = input #Storing X
    return  self.input@self.weights + self.bias

  #################################################
  # Q3 Implementing Backward Pass for Linear
  #################################################
  def backward(self, grad):
    self.grad_weights = self.input.T@grad
    self.grad_bias = np.sum(grad, axis=0)
    return grad@self.weights.T
    
  def step(self, step_size):
    self.weights -= step_size*self.grad_weights
    self.bias -= step_size*self.grad_bias


###############################################
# Instructor code below. Worth understanding
# but don't need to modify for base assignment
###############################################



class FeedForwardNeuralNetwork:

  def __init__(self, input_dim, output_dim, hidden_dim, num_layers, activation="ReLU"):

    if num_layers == 1:
      self.layers = [LinearLayer(input_dim, output_dim)]
    else:
      self.layers = [LinearLayer(input_dim, hidden_dim)]
      self.layers.append(Sigmoid() if activation=="Sigmoid" else ReLU())
      for i in range(num_layers-2):
        self.layers.append(LinearLayer(hidden_dim, hidden_dim))
        self.layers.append(Sigmoid() if activation=="Sigmoid" else ReLU())
      self.layers.append(LinearLayer(hidden_dim, output_dim))

  def forward(self, X):
    for layer in self.layers:
      X = layer.forward(X)
    return X

  def backward(self, grad):
    for layer in reversed(self.layers):
      grad = layer.backward(grad)

  def step(self, step_size=0.001):
    for layer in self.layers:
      layer.step(step_size)





# Sigmoid or Logistic Activation Function
class Sigmoid:

  # Given the input, apply the sigmoid function
  # store the output value for use in the backwards pass
  def forward(self, input):
    self.act = 1/(1+np.exp(-input))
    return self.act
  
  # Compute the gradient of the output with respect to the input
  # self.act*(1-self.act) and then multiply by the loss gradient with
  # respect to the output to produce the loss gradient with respect to the input
  def backward(self, grad):
    return grad * self.act * (1-self.act)

  # The Sigmoid has no parameters so nothing to do during a gradient descent step
  def step(self,step_size):
    return

# Rectified Linear Unit Activation Function
class ReLU:

  # Forward pass is max(0,input)
  def forward(self, input):
    self.mask = (input > 0)
    return input * self.mask
  
  # Backward pass masks out same elements
  def backward(self, grad):
    return grad * self.mask

  # No parameters so nothing to do during a gradient descent step
  def step(self,step_size):
    return



#####################################################
# Utility Functions for Computing Loss / Val Metrics
#####################################################
def softmax(x):
  x -= np.max(x,axis=1)[:,np.newaxis]  # Numerical stability trick
  return np.exp(x) / (np.sum(np.exp(x),axis=1)[:,np.newaxis])


class CrossEntropySoftmax:

  def forward(self, logits, labels):
    self.probs = softmax(logits)
    self.labels = labels
    return -np.mean(np.log(self.probs[np.arange(len(self.probs))[:,np.newaxis],labels]+0.00001))

  def backward(self):
    grad = self.probs
    grad[np.arange(len(self.probs))[:,np.newaxis],self.labels] -=  1
    return  grad.astype(np.float64)/len(self.probs)


def evaluateValidation(model, X_val, Y_val, batch_size):
  val_loss_running = 0
  val_acc_running = 0
  j=0

  lossFunc = CrossEntropySoftmax()

  while j < len(X_val):
    b = min(batch_size, len(X_val)-j)
    X_batch = X_val[j:j+b]
    Y_batch = Y_val[j:j+b].astype(np.int)
   
    logits = model.forward(X_batch)
    loss = lossFunc.forward(logits, Y_batch)
    acc = np.mean( np.argmax(logits,axis=1)[:,np.newaxis] == Y_batch)

    val_loss_running += loss*b
    val_acc_running += acc*b
       
    j+=batch_size

  return val_loss_running/len(X_val), val_acc_running/len(X_val)







#####################################################
# Utility Functions for Loading and Displaying Data
#####################################################
def loadData(normalize = True):
  train = np.loadtxt("mnist_small_train.csv", delimiter=",", dtype=np.float64)
  val = np.loadtxt("mnist_small_val.csv", delimiter=",", dtype=np.float64)
  test = np.loadtxt("mnist_small_test.csv", delimiter=",", dtype=np.float64)

  # Normalize Our Data
  if normalize:
    X_train = train[:,:-1]/256-0.5
    X_val = val[:,:-1]/256-0.5
    X_test = test/256-0.5
  else:
    X_train = train[:,:-1]
    X_val = val[:,:-1]
    X_test = test

  Y_train = train[:,-1].astype(np.int)[:,np.newaxis]
  Y_val = val[:,-1].astype(np.int)[:,np.newaxis]

  logging.info("Loaded train: " + str(X_train.shape))
  logging.info("Loaded val: " + str(X_val.shape))
  logging.info("Loaded test: "+ str(X_test.shape))

  return X_train, Y_train, X_val, Y_val, X_test


def displayExample(x):
  plt.imshow(x.reshape(28,28),cmap="gray")
  plt.show()


if __name__=="__main__":
  main()
# Out:
# /var/folders/j7/v7fxqplj159bfs5m8bw5sdn00000gn/T/ipykernel_57331/3759751397.py:300: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = train[:,-1].astype(np.int)[:,np.newaxis]
# /var/folders/j7/v7fxqplj159bfs5m8bw5sdn00000gn/T/ipykernel_57331/3759751397.py:301: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_val = val[:,-1].astype(np.int)[:,np.newaxis]
# 2022-11-15 11:20:18 INFO     Loaded train: (5000, 784)
# 2022-11-15 11:20:18 INFO     Loaded val: (1000, 784)
# 2022-11-15 11:20:18 INFO     Loaded test: (4220, 784)
# /var/folders/j7/v7fxqplj159bfs5m8bw5sdn00000gn/T/ipykernel_57331/3759751397.py:62: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_batch = Y_train[inds[j:j+b]].astype(np.int)
# /var/folders/j7/v7fxqplj159bfs5m8bw5sdn00000gn/T/ipykernel_57331/3759751397.py:263: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_batch = Y_val[j:j+b].astype(np.int)
# 2022-11-15 11:20:18 INFO     [Epoch   0]   Loss:     2.519     Train Acc:      9.82%      Val Acc:       9.4%
# 2022-11-15 11:20:18 INFO     [Epoch   1]   Loss:     2.384     Train Acc:      10.7%      Val Acc:       9.8%
# 2022-11-15 11:20:18 INFO     [Epoch   2]   Loss:     2.319     Train Acc:     14.94%      Val Acc:      16.6%
# 2022-11-15 11:20:18 INFO     [Epoch   3]   Loss:     2.279     Train Acc:     21.46%      Val Acc:      23.0%
# 2022-11-15 11:20:18 INFO     [Epoch   4]   Loss:      2.25     Train Acc:     26.18%      Val Acc:      28.0%
# 2022-11-15 11:20:18 INFO     [Epoch   5]   Loss:     2.226     Train Acc:     30.44%      Val Acc:      34.3%
# 2022-11-15 11:20:18 INFO     [Epoch   6]   Loss:     2.205     Train Acc:      35.4%      Val Acc:      38.9%
# 2022-11-15 11:20:18 INFO     [Epoch   7]   Loss:     2.184     Train Acc:     39.08%      Val Acc:      42.1%
# 2022-11-15 11:20:18 INFO     [Epoch   8]   Loss:     2.164     Train Acc:     41.96%      Val Acc:      44.5%
# 2022-11-15 11:20:18 INFO     [Epoch   9]   Loss:     2.144     Train Acc:      44.3%      Val Acc:      46.9%
# 2022-11-15 11:20:18 INFO     [Epoch  10]   Loss:     2.125     Train Acc:     46.76%      Val Acc:      48.6%
# 2022-11-15 11:20:18 INFO     [Epoch  11]   Loss:     2.105     Train Acc:     48.76%      Val Acc:      50.1%
# 2022-11-15 11:20:18 INFO     [Epoch  12]   Loss:     2.085     Train Acc:     50.36%      Val Acc:      51.8%
# 2022-11-15 11:20:18 INFO     [Epoch  13]   Loss:     2.066     Train Acc:     52.36%      Val Acc:      53.5%
# 2022-11-15 11:20:18 INFO     [Epoch  14]   Loss:     2.046     Train Acc:     53.48%      Val Acc:      54.5%
# 2022-11-15 11:20:18 INFO     [Epoch  15]   Loss:     2.027     Train Acc:     55.56%      Val Acc:      56.0%
# 2022-11-15 11:20:18 INFO     [Epoch  16]   Loss:     2.008     Train Acc:     56.76%      Val Acc:      57.9%
# 2022-11-15 11:20:18 INFO     [Epoch  17]   Loss:     1.989     Train Acc:     58.62%      Val Acc:      58.9%
# 2022-11-15 11:20:18 INFO     [Epoch  18]   Loss:     1.971     Train Acc:     59.52%      Val Acc:      60.3%
# 2022-11-15 11:20:19 INFO     [Epoch  19]   Loss:     1.953     Train Acc:     60.88%      Val Acc:      62.2%
# 2022-11-15 11:20:19 INFO     [Epoch  20]   Loss:     1.935     Train Acc:     62.04%      Val Acc:      63.1%
# 2022-11-15 11:20:19 INFO     [Epoch  21]   Loss:     1.917     Train Acc:     62.92%      Val Acc:      64.3%
# 2022-11-15 11:20:19 INFO     [Epoch  22]   Loss:     1.899     Train Acc:     63.96%      Val Acc:      64.7%
# 2022-11-15 11:20:19 INFO     [Epoch  23]   Loss:     1.882     Train Acc:     64.84%      Val Acc:      65.7%
# 2022-11-15 11:20:19 INFO     [Epoch  24]   Loss:     1.865     Train Acc:     65.78%      Val Acc:      66.1%
# 2022-11-15 11:20:19 INFO     [Epoch  25]   Loss:     1.848     Train Acc:      66.2%      Val Acc:      66.6%
# 2022-11-15 11:20:19 INFO     [Epoch  26]   Loss:     1.831     Train Acc:      67.4%      Val Acc:      67.0%
# 2022-11-15 11:20:19 INFO     [Epoch  27]   Loss:     1.814     Train Acc:     67.44%      Val Acc:      68.1%
# 2022-11-15 11:20:19 INFO     [Epoch  28]   Loss:     1.798     Train Acc:      68.1%      Val Acc:      68.9%
# 2022-11-15 11:20:19 INFO     [Epoch  29]   Loss:     1.782     Train Acc:     68.48%      Val Acc:      69.2%
# 2022-11-15 11:20:19 INFO     [Epoch  30]   Loss:     1.766     Train Acc:     69.04%      Val Acc:      69.8%
# 2022-11-15 11:20:19 INFO     [Epoch  31]   Loss:      1.75     Train Acc:     69.38%      Val Acc:      70.5%
# 2022-11-15 11:20:19 INFO     [Epoch  32]   Loss:     1.734     Train Acc:     69.76%      Val Acc:      70.9%
# 2022-11-15 11:20:19 INFO     [Epoch  33]   Loss:     1.719     Train Acc:     70.18%      Val Acc:      71.1%
# 2022-11-15 11:20:19 INFO     [Epoch  34]   Loss:     1.704     Train Acc:     70.42%      Val Acc:      71.3%
# 2022-11-15 11:20:19 INFO     [Epoch  35]   Loss:     1.689     Train Acc:     70.94%      Val Acc:      71.6%
# 2022-11-15 11:20:19 INFO     [Epoch  36]   Loss:     1.675     Train Acc:     71.22%      Val Acc:      72.2%
# 2022-11-15 11:20:19 INFO     [Epoch  37]   Loss:      1.66     Train Acc:     71.44%      Val Acc:      72.4%
# 2022-11-15 11:20:19 INFO     [Epoch  38]   Loss:     1.646     Train Acc:     71.56%      Val Acc:      72.5%
# 2022-11-15 11:20:19 INFO     [Epoch  39]   Loss:     1.632     Train Acc:     71.86%      Val Acc:      72.9%
# 2022-11-15 11:20:19 INFO     [Epoch  40]   Loss:     1.618     Train Acc:     71.72%      Val Acc:      73.2%
# 2022-11-15 11:20:19 INFO     [Epoch  41]   Loss:     1.604     Train Acc:     72.18%      Val Acc:      72.9%
# 2022-11-15 11:20:19 INFO     [Epoch  42]   Loss:     1.591     Train Acc:     72.48%      Val Acc:      72.9%
# 2022-11-15 11:20:20 INFO     [Epoch  43]   Loss:     1.578     Train Acc:      72.7%      Val Acc:      73.3%
# 2022-11-15 11:20:20 INFO     [Epoch  44]   Loss:     1.565     Train Acc:      72.8%      Val Acc:      73.3%
# 2022-11-15 11:20:20 INFO     [Epoch  45]   Loss:     1.552     Train Acc:     72.88%      Val Acc:      73.9%
# 2022-11-15 11:20:20 INFO     [Epoch  46]   Loss:     1.539     Train Acc:      73.2%      Val Acc:      74.1%
# 2022-11-15 11:20:20 INFO     [Epoch  47]   Loss:     1.526     Train Acc:     73.14%      Val Acc:      74.6%
# 2022-11-15 11:20:20 INFO     [Epoch  48]   Loss:     1.514     Train Acc:     73.42%      Val Acc:      74.7%
# 2022-11-15 11:20:20 INFO     [Epoch  49]   Loss:     1.502     Train Acc:     73.38%      Val Acc:      74.8%
# 2022-11-15 11:20:20 INFO     [Epoch  50]   Loss:      1.49     Train Acc:     73.62%      Val Acc:      75.0%
# 2022-11-15 11:20:20 INFO     [Epoch  51]   Loss:     1.478     Train Acc:     73.84%      Val Acc:      75.6%
# 2022-11-15 11:20:20 INFO     [Epoch  52]   Loss:     1.466     Train Acc:     74.04%      Val Acc:      75.9%
# 2022-11-15 11:20:20 INFO     [Epoch  53]   Loss:     1.455     Train Acc:      74.1%      Val Acc:      76.2%
# 2022-11-15 11:20:20 INFO     [Epoch  54]   Loss:     1.444     Train Acc:     74.48%      Val Acc:      76.4%
# 2022-11-15 11:20:20 INFO     [Epoch  55]   Loss:     1.432     Train Acc:     74.66%      Val Acc:      76.6%
# 2022-11-15 11:20:20 INFO     [Epoch  56]   Loss:     1.421     Train Acc:     74.58%      Val Acc:      76.6%
# 2022-11-15 11:20:20 INFO     [Epoch  57]   Loss:      1.41     Train Acc:     74.96%      Val Acc:      76.9%
# 2022-11-15 11:20:20 INFO     [Epoch  58]   Loss:       1.4     Train Acc:     75.04%      Val Acc:      77.1%
# 2022-11-15 11:20:20 INFO     [Epoch  59]   Loss:     1.389     Train Acc:      75.1%      Val Acc:      77.3%
# 2022-11-15 11:20:20 INFO     [Epoch  60]   Loss:     1.379     Train Acc:     75.24%      Val Acc:      77.2%
# 2022-11-15 11:20:20 INFO     [Epoch  61]   Loss:     1.368     Train Acc:     75.58%      Val Acc:      77.3%
# 2022-11-15 11:20:20 INFO     [Epoch  62]   Loss:     1.358     Train Acc:     75.84%      Val Acc:      77.3%
# 2022-11-15 11:20:20 INFO     [Epoch  63]   Loss:     1.348     Train Acc:     75.76%      Val Acc:      77.5%
# 2022-11-15 11:20:20 INFO     [Epoch  64]   Loss:     1.338     Train Acc:      75.9%      Val Acc:      77.4%
# 2022-11-15 11:20:20 INFO     [Epoch  65]   Loss:     1.328     Train Acc:     76.24%      Val Acc:      77.7%
# 2022-11-15 11:20:20 INFO     [Epoch  66]   Loss:     1.319     Train Acc:     76.28%      Val Acc:      77.8%
# 2022-11-15 11:20:20 INFO     [Epoch  67]   Loss:     1.309     Train Acc:     76.42%      Val Acc:      78.1%
# 2022-11-15 11:20:20 INFO     [Epoch  68]   Loss:       1.3     Train Acc:     76.38%      Val Acc:      78.2%
# 2022-11-15 11:20:21 INFO     [Epoch  69]   Loss:      1.29     Train Acc:      76.6%      Val Acc:      78.5%
# 2022-11-15 11:20:21 INFO     [Epoch  70]   Loss:     1.281     Train Acc:     76.76%      Val Acc:      78.9%
# 2022-11-15 11:20:21 INFO     [Epoch  71]   Loss:     1.272     Train Acc:     76.88%      Val Acc:      79.3%
# 2022-11-15 11:20:21 INFO     [Epoch  72]   Loss:     1.263     Train Acc:      77.1%      Val Acc:      79.5%
# 2022-11-15 11:20:21 INFO     [Epoch  73]   Loss:     1.254     Train Acc:     77.08%      Val Acc:      79.6%
# 2022-11-15 11:20:21 INFO     [Epoch  74]   Loss:     1.246     Train Acc:     77.18%      Val Acc:      79.9%
# 2022-11-15 11:20:21 INFO     [Epoch  75]   Loss:     1.237     Train Acc:     77.38%      Val Acc:      80.4%
# 2022-11-15 11:20:21 INFO     [Epoch  76]   Loss:     1.229     Train Acc:     77.58%      Val Acc:      80.5%
# 2022-11-15 11:20:21 INFO     [Epoch  77]   Loss:      1.22     Train Acc:     77.66%      Val Acc:      80.8%
# 2022-11-15 11:20:21 INFO     [Epoch  78]   Loss:     1.212     Train Acc:      77.7%      Val Acc:      80.8%
# 2022-11-15 11:20:21 INFO     [Epoch  79]   Loss:     1.204     Train Acc:      78.0%      Val Acc:      81.1%
# 2022-11-15 11:20:21 INFO     [Epoch  80]   Loss:     1.196     Train Acc:     78.02%      Val Acc:      81.4%
# 2022-11-15 11:20:21 INFO     [Epoch  81]   Loss:     1.188     Train Acc:     78.16%      Val Acc:      81.5%
# 2022-11-15 11:20:21 INFO     [Epoch  82]   Loss:      1.18     Train Acc:      78.4%      Val Acc:      81.6%
# 2022-11-15 11:20:21 INFO     [Epoch  83]   Loss:     1.172     Train Acc:     78.52%      Val Acc:      81.8%
# 2022-11-15 11:20:21 INFO     [Epoch  84]   Loss:     1.165     Train Acc:     78.62%      Val Acc:      81.9%
# 2022-11-15 11:20:21 INFO     [Epoch  85]   Loss:     1.157     Train Acc:     78.72%      Val Acc:      81.9%
# 2022-11-15 11:20:21 INFO     [Epoch  86]   Loss:      1.15     Train Acc:     78.86%      Val Acc:      81.9%
# 2022-11-15 11:20:21 INFO     [Epoch  87]   Loss:     1.142     Train Acc:     78.88%      Val Acc:      81.9%
# 2022-11-15 11:20:21 INFO     [Epoch  88]   Loss:     1.135     Train Acc:     78.92%      Val Acc:      81.8%
# 2022-11-15 11:20:21 INFO     [Epoch  89]   Loss:     1.128     Train Acc:     79.18%      Val Acc:      81.9%
# 2022-11-15 11:20:21 INFO     [Epoch  90]   Loss:     1.121     Train Acc:     79.08%      Val Acc:      82.0%
# 2022-11-15 11:20:21 INFO     [Epoch  91]   Loss:     1.113     Train Acc:     79.28%      Val Acc:      82.2%
# 2022-11-15 11:20:21 INFO     [Epoch  92]   Loss:     1.107     Train Acc:     79.38%      Val Acc:      82.2%
# 2022-11-15 11:20:21 INFO     [Epoch  93]   Loss:       1.1     Train Acc:     79.56%      Val Acc:      82.4%
# 2022-11-15 11:20:21 INFO     [Epoch  94]   Loss:     1.093     Train Acc:     79.72%      Val Acc:      82.8%
# 2022-11-15 11:20:21 INFO     [Epoch  95]   Loss:     1.086     Train Acc:     79.68%      Val Acc:      82.9%
# 2022-11-15 11:20:21 INFO     [Epoch  96]   Loss:      1.08     Train Acc:     79.76%      Val Acc:      82.9%
# 2022-11-15 11:20:22 INFO     [Epoch  97]   Loss:     1.073     Train Acc:     79.94%      Val Acc:      83.2%
# 2022-11-15 11:20:22 INFO     [Epoch  98]   Loss:     1.067     Train Acc:     79.98%      Val Acc:      83.2%
# 2022-11-15 11:20:22 INFO     [Epoch  99]   Loss:      1.06     Train Acc:     80.14%      Val Acc:      83.2%
# 2022-11-15 11:20:22 INFO     [Epoch 100]   Loss:     1.054     Train Acc:     80.18%      Val Acc:      83.3%
# 2022-11-15 11:20:22 INFO     [Epoch 101]   Loss:     1.048     Train Acc:     80.34%      Val Acc:      83.4%
# 2022-11-15 11:20:22 INFO     [Epoch 102]   Loss:     1.042     Train Acc:     80.48%      Val Acc:      83.4%
# 2022-11-15 11:20:22 INFO     [Epoch 103]   Loss:     1.036     Train Acc:      80.6%      Val Acc:      83.5%
# 2022-11-15 11:20:22 INFO     [Epoch 104]   Loss:      1.03     Train Acc:      80.7%      Val Acc:      83.7%
# 2022-11-15 11:20:22 INFO     [Epoch 105]   Loss:     1.024     Train Acc:      80.9%      Val Acc:      83.8%
# 2022-11-15 11:20:22 INFO     [Epoch 106]   Loss:     1.018     Train Acc:     80.94%      Val Acc:      84.0%
# 2022-11-15 11:20:22 INFO     [Epoch 107]   Loss:     1.012     Train Acc:      80.9%      Val Acc:      84.1%
# 2022-11-15 11:20:22 INFO     [Epoch 108]   Loss:     1.006     Train Acc:     81.18%      Val Acc:      84.1%
# 2022-11-15 11:20:22 INFO     [Epoch 109]   Loss:     1.001     Train Acc:     81.28%      Val Acc:      84.2%
# 2022-11-15 11:20:22 INFO     [Epoch 110]   Loss:     0.995     Train Acc:     81.32%      Val Acc:      84.3%
# 2022-11-15 11:20:22 INFO     [Epoch 111]   Loss:    0.9894     Train Acc:     81.38%      Val Acc:      84.4%
# 2022-11-15 11:20:22 INFO     [Epoch 112]   Loss:     0.984     Train Acc:     81.52%      Val Acc:      84.4%
# 2022-11-15 11:20:22 INFO     [Epoch 113]   Loss:    0.9786     Train Acc:     81.62%      Val Acc:      84.4%
# 2022-11-15 11:20:22 INFO     [Epoch 114]   Loss:    0.9732     Train Acc:      81.6%      Val Acc:      84.6%
# 2022-11-15 11:20:22 INFO     [Epoch 115]   Loss:    0.9679     Train Acc:     81.74%      Val Acc:      84.7%
# 2022-11-15 11:20:22 INFO     [Epoch 116]   Loss:    0.9627     Train Acc:     81.68%      Val Acc:      84.7%
# 2022-11-15 11:20:22 INFO     [Epoch 117]   Loss:    0.9575     Train Acc:     81.86%      Val Acc:      84.9%
# 2022-11-15 11:20:22 INFO     [Epoch 118]   Loss:    0.9524     Train Acc:      81.9%      Val Acc:      84.7%
# 2022-11-15 11:20:22 INFO     [Epoch 119]   Loss:    0.9474     Train Acc:     82.02%      Val Acc:      84.9%
# 2022-11-15 11:20:22 INFO     [Epoch 120]   Loss:    0.9424     Train Acc:     82.12%      Val Acc:      85.1%
# 2022-11-15 11:20:22 INFO     [Epoch 121]   Loss:    0.9375     Train Acc:     82.28%      Val Acc:      85.2%
# 2022-11-15 11:20:22 INFO     [Epoch 122]   Loss:    0.9326     Train Acc:     82.18%      Val Acc:      85.1%
# 2022-11-15 11:20:22 INFO     [Epoch 123]   Loss:    0.9278     Train Acc:     82.36%      Val Acc:      85.3%
# 2022-11-15 11:20:23 INFO     [Epoch 124]   Loss:     0.923     Train Acc:     82.38%      Val Acc:      85.4%
# 2022-11-15 11:20:23 INFO     [Epoch 125]   Loss:    0.9183     Train Acc:      82.5%      Val Acc:      85.5%
# 2022-11-15 11:20:23 INFO     [Epoch 126]   Loss:    0.9136     Train Acc:     82.66%      Val Acc:      85.6%
# 2022-11-15 11:20:23 INFO     [Epoch 127]   Loss:     0.909     Train Acc:      82.7%      Val Acc:      85.6%
# 2022-11-15 11:20:23 INFO     [Epoch 128]   Loss:    0.9044     Train Acc:     82.54%      Val Acc:      85.7%
# 2022-11-15 11:20:23 INFO     [Epoch 129]   Loss:    0.8999     Train Acc:     82.76%      Val Acc:      85.8%
# 2022-11-15 11:20:23 INFO     [Epoch 130]   Loss:    0.8955     Train Acc:     82.76%      Val Acc:      85.7%
# 2022-11-15 11:20:23 INFO     [Epoch 131]   Loss:     0.891     Train Acc:      82.8%      Val Acc:      85.9%
# 2022-11-15 11:20:23 INFO     [Epoch 132]   Loss:    0.8867     Train Acc:     82.98%      Val Acc:      86.0%
# 2022-11-15 11:20:23 INFO     [Epoch 133]   Loss:    0.8824     Train Acc:     83.02%      Val Acc:      86.0%
# 2022-11-15 11:20:23 INFO     [Epoch 134]   Loss:     0.878     Train Acc:     83.14%      Val Acc:      86.1%
# 2022-11-15 11:20:23 INFO     [Epoch 135]   Loss:    0.8738     Train Acc:     83.32%      Val Acc:      86.0%
# 2022-11-15 11:20:23 INFO     [Epoch 136]   Loss:    0.8697     Train Acc:     83.28%      Val Acc:      86.0%
# 2022-11-15 11:20:23 INFO     [Epoch 137]   Loss:    0.8655     Train Acc:     83.26%      Val Acc:      86.3%
# 2022-11-15 11:20:23 INFO     [Epoch 138]   Loss:    0.8613     Train Acc:     83.44%      Val Acc:      86.2%
# 2022-11-15 11:20:23 INFO     [Epoch 139]   Loss:    0.8573     Train Acc:     83.46%      Val Acc:      86.5%
# 2022-11-15 11:20:23 INFO     [Epoch 140]   Loss:    0.8533     Train Acc:     83.52%      Val Acc:      86.9%
# 2022-11-15 11:20:23 INFO     [Epoch 141]   Loss:    0.8494     Train Acc:     83.62%      Val Acc:      87.0%
# 2022-11-15 11:20:23 INFO     [Epoch 142]   Loss:    0.8454     Train Acc:     83.66%      Val Acc:      87.2%
# 2022-11-15 11:20:23 INFO     [Epoch 143]   Loss:    0.8415     Train Acc:     83.76%      Val Acc:      87.2%
# 2022-11-15 11:20:23 INFO     [Epoch 144]   Loss:    0.8376     Train Acc:     83.84%      Val Acc:      87.3%
# 2022-11-15 11:20:23 INFO     [Epoch 145]   Loss:    0.8339     Train Acc:      83.9%      Val Acc:      87.5%
# 2022-11-15 11:20:23 INFO     [Epoch 146]   Loss:    0.8301     Train Acc:     83.98%      Val Acc:      87.5%
# 2022-11-15 11:20:23 INFO     [Epoch 147]   Loss:    0.8263     Train Acc:     83.94%      Val Acc:      87.6%
# 2022-11-15 11:20:23 INFO     [Epoch 148]   Loss:    0.8226     Train Acc:     84.08%      Val Acc:      87.5%
# 2022-11-15 11:20:23 INFO     [Epoch 149]   Loss:     0.819     Train Acc:     84.16%      Val Acc:      87.5%
# 2022-11-15 11:20:23 INFO     [Epoch 150]   Loss:    0.8154     Train Acc:     84.34%      Val Acc:      87.6%
# 2022-11-15 11:20:23 INFO     [Epoch 151]   Loss:    0.8117     Train Acc:     84.18%      Val Acc:      87.5%
# 2022-11-15 11:20:23 INFO     [Epoch 152]   Loss:    0.8082     Train Acc:     84.38%      Val Acc:      87.7%
# 2022-11-15 11:20:23 INFO     [Epoch 153]   Loss:    0.8047     Train Acc:     84.34%      Val Acc:      87.8%
# 2022-11-15 11:20:24 INFO     [Epoch 154]   Loss:    0.8012     Train Acc:     84.48%      Val Acc:      87.9%
# 2022-11-15 11:20:24 INFO     [Epoch 155]   Loss:    0.7978     Train Acc:     84.54%      Val Acc:      87.9%
# 2022-11-15 11:20:24 INFO     [Epoch 156]   Loss:    0.7944     Train Acc:     84.52%      Val Acc:      87.9%
# 2022-11-15 11:20:24 INFO     [Epoch 157]   Loss:    0.7909     Train Acc:     84.46%      Val Acc:      87.9%
# 2022-11-15 11:20:24 INFO     [Epoch 158]   Loss:    0.7876     Train Acc:     84.62%      Val Acc:      88.0%
# 2022-11-15 11:20:24 INFO     [Epoch 159]   Loss:    0.7843     Train Acc:     84.64%      Val Acc:      88.0%
# 2022-11-15 11:20:24 INFO     [Epoch 160]   Loss:     0.781     Train Acc:      84.7%      Val Acc:      88.0%
# 2022-11-15 11:20:24 INFO     [Epoch 161]   Loss:    0.7778     Train Acc:     84.86%      Val Acc:      88.1%
# 2022-11-15 11:20:24 INFO     [Epoch 162]   Loss:    0.7746     Train Acc:     84.88%      Val Acc:      88.1%
# 2022-11-15 11:20:24 INFO     [Epoch 163]   Loss:    0.7714     Train Acc:     84.78%      Val Acc:      88.0%
# 2022-11-15 11:20:24 INFO     [Epoch 164]   Loss:    0.7683     Train Acc:     84.86%      Val Acc:      88.2%
# 2022-11-15 11:20:24 INFO     [Epoch 165]   Loss:    0.7651     Train Acc:     85.06%      Val Acc:      88.2%
# 2022-11-15 11:20:24 INFO     [Epoch 166]   Loss:     0.762     Train Acc:     85.16%      Val Acc:      88.2%
# 2022-11-15 11:20:24 INFO     [Epoch 167]   Loss:     0.759     Train Acc:     85.06%      Val Acc:      88.4%
# 2022-11-15 11:20:24 INFO     [Epoch 168]   Loss:    0.7559     Train Acc:      85.1%      Val Acc:      88.5%
# 2022-11-15 11:20:24 INFO     [Epoch 169]   Loss:    0.7529     Train Acc:      85.1%      Val Acc:      88.4%
# 2022-11-15 11:20:24 INFO     [Epoch 170]   Loss:    0.7499     Train Acc:     85.22%      Val Acc:      88.7%
# 2022-11-15 11:20:24 INFO     [Epoch 171]   Loss:     0.747     Train Acc:     85.26%      Val Acc:      88.6%
# 2022-11-15 11:20:24 INFO     [Epoch 172]   Loss:    0.7441     Train Acc:     85.26%      Val Acc:      88.7%
# 2022-11-15 11:20:24 INFO     [Epoch 173]   Loss:    0.7412     Train Acc:      85.4%      Val Acc:      88.7%
# 2022-11-15 11:20:24 INFO     [Epoch 174]   Loss:    0.7383     Train Acc:     85.38%      Val Acc:      88.7%
# 2022-11-15 11:20:24 INFO     [Epoch 175]   Loss:    0.7355     Train Acc:     85.38%      Val Acc:      88.7%
# 2022-11-15 11:20:24 INFO     [Epoch 176]   Loss:    0.7327     Train Acc:      85.6%      Val Acc:      88.7%
# 2022-11-15 11:20:24 INFO     [Epoch 177]   Loss:    0.7299     Train Acc:     85.54%      Val Acc:      88.6%
# 2022-11-15 11:20:24 INFO     [Epoch 178]   Loss:    0.7271     Train Acc:     85.56%      Val Acc:      88.7%
# 2022-11-15 11:20:24 INFO     [Epoch 179]   Loss:    0.7244     Train Acc:     85.72%      Val Acc:      88.7%
# 2022-11-15 11:20:24 INFO     [Epoch 180]   Loss:    0.7217     Train Acc:     85.82%      Val Acc:      88.8%
# 2022-11-15 11:20:24 INFO     [Epoch 181]   Loss:    0.7189     Train Acc:      85.7%      Val Acc:      88.8%
# 2022-11-15 11:20:25 INFO     [Epoch 182]   Loss:    0.7163     Train Acc:     85.78%      Val Acc:      88.8%
# 2022-11-15 11:20:25 INFO     [Epoch 183]   Loss:    0.7137     Train Acc:      85.8%      Val Acc:      88.9%
# 2022-11-15 11:20:25 INFO     [Epoch 184]   Loss:     0.711     Train Acc:     85.88%      Val Acc:      88.9%
# 2022-11-15 11:20:25 INFO     [Epoch 185]   Loss:    0.7084     Train Acc:     85.88%      Val Acc:      88.9%
# 2022-11-15 11:20:25 INFO     [Epoch 186]   Loss:    0.7059     Train Acc:     85.92%      Val Acc:      89.0%
# 2022-11-15 11:20:25 INFO     [Epoch 187]   Loss:    0.7033     Train Acc:     86.04%      Val Acc:      89.0%
# 2022-11-15 11:20:25 INFO     [Epoch 188]   Loss:    0.7008     Train Acc:     85.96%      Val Acc:      89.0%
# 2022-11-15 11:20:25 INFO     [Epoch 189]   Loss:    0.6983     Train Acc:     86.02%      Val Acc:      89.0%
# 2022-11-15 11:20:25 INFO     [Epoch 190]   Loss:    0.6958     Train Acc:     86.06%      Val Acc:      89.0%
# 2022-11-15 11:20:25 INFO     [Epoch 191]   Loss:    0.6934     Train Acc:     86.12%      Val Acc:      89.0%
# 2022-11-15 11:20:25 INFO     [Epoch 192]   Loss:    0.6909     Train Acc:     86.08%      Val Acc:      89.0%
# 2022-11-15 11:20:25 INFO     [Epoch 193]   Loss:    0.6885     Train Acc:     86.18%      Val Acc:      89.0%
# 2022-11-15 11:20:25 INFO     [Epoch 194]   Loss:    0.6861     Train Acc:     86.24%      Val Acc:      89.0%
# 2022-11-15 11:20:25 INFO     [Epoch 195]   Loss:    0.6837     Train Acc:     86.26%      Val Acc:      89.0%
# 2022-11-15 11:20:25 INFO     [Epoch 196]   Loss:    0.6813     Train Acc:     86.32%      Val Acc:      89.0%
# 2022-11-15 11:20:25 INFO     [Epoch 197]   Loss:     0.679     Train Acc:     86.32%      Val Acc:      89.0%
# 2022-11-15 11:20:25 INFO     [Epoch 198]   Loss:    0.6767     Train Acc:     86.44%      Val Acc:      88.9%
# 2022-11-15 11:20:25 INFO     [Epoch 199]   Loss:    0.6744     Train Acc:     86.42%      Val Acc:      89.1%
# 2022-11-15 11:20:25 INFO     [Epoch 200]   Loss:    0.6722     Train Acc:      86.6%      Val Acc:      89.2%
# 2022-11-15 11:20:25 INFO     [Epoch 201]   Loss:    0.6699     Train Acc:     86.54%      Val Acc:      89.3%
# 2022-11-15 11:20:25 INFO     [Epoch 202]   Loss:    0.6676     Train Acc:     86.66%      Val Acc:      89.3%
# 2022-11-15 11:20:25 INFO     [Epoch 203]   Loss:    0.6654     Train Acc:     86.66%      Val Acc:      89.3%
# 2022-11-15 11:20:25 INFO     [Epoch 204]   Loss:    0.6632     Train Acc:     86.68%      Val Acc:      89.2%
# 2022-11-15 11:20:25 INFO     [Epoch 205]   Loss:     0.661     Train Acc:     86.84%      Val Acc:      89.2%
# 2022-11-15 11:20:25 INFO     [Epoch 206]   Loss:    0.6589     Train Acc:     86.84%      Val Acc:      89.3%
# 2022-11-15 11:20:25 INFO     [Epoch 207]   Loss:    0.6568     Train Acc:     86.84%      Val Acc:      89.2%
# 2022-11-15 11:20:25 INFO     [Epoch 208]   Loss:    0.6546     Train Acc:     86.94%      Val Acc:      89.2%
# 2022-11-15 11:20:25 INFO     [Epoch 209]   Loss:    0.6525     Train Acc:     86.92%      Val Acc:      89.2%
# 2022-11-15 11:20:26 INFO     [Epoch 210]   Loss:    0.6504     Train Acc:     86.94%      Val Acc:      89.2%
# 2022-11-15 11:20:26 INFO     [Epoch 211]   Loss:    0.6483     Train Acc:      86.9%      Val Acc:      89.2%
# 2022-11-15 11:20:26 INFO     [Epoch 212]   Loss:    0.6463     Train Acc:     86.96%      Val Acc:      89.2%
# 2022-11-15 11:20:26 INFO     [Epoch 213]   Loss:    0.6442     Train Acc:     86.98%      Val Acc:      89.2%
# 2022-11-15 11:20:26 INFO     [Epoch 214]   Loss:    0.6422     Train Acc:     87.04%      Val Acc:      89.2%
# 2022-11-15 11:20:26 INFO     [Epoch 215]   Loss:    0.6402     Train Acc:     86.94%      Val Acc:      89.2%
# 2022-11-15 11:20:26 INFO     [Epoch 216]   Loss:    0.6382     Train Acc:     86.98%      Val Acc:      89.3%
# 2022-11-15 11:20:26 INFO     [Epoch 217]   Loss:    0.6362     Train Acc:     87.02%      Val Acc:      89.5%
# 2022-11-15 11:20:26 INFO     [Epoch 218]   Loss:    0.6343     Train Acc:      87.1%      Val Acc:      89.4%
# 2022-11-15 11:20:26 INFO     [Epoch 219]   Loss:    0.6323     Train Acc:     87.14%      Val Acc:      89.4%
# 2022-11-15 11:20:26 INFO     [Epoch 220]   Loss:    0.6304     Train Acc:     87.12%      Val Acc:      89.4%
# 2022-11-15 11:20:26 INFO     [Epoch 221]   Loss:    0.6284     Train Acc:     87.12%      Val Acc:      89.5%
# 2022-11-15 11:20:26 INFO     [Epoch 222]   Loss:    0.6266     Train Acc:     87.14%      Val Acc:      89.5%
# 2022-11-15 11:20:26 INFO     [Epoch 223]   Loss:    0.6247     Train Acc:      87.2%      Val Acc:      89.5%
# 2022-11-15 11:20:26 INFO     [Epoch 224]   Loss:    0.6228     Train Acc:     87.26%      Val Acc:      89.5%
# 2022-11-15 11:20:26 INFO     [Epoch 225]   Loss:    0.6209     Train Acc:      87.3%      Val Acc:      89.5%
# 2022-11-15 11:20:26 INFO     [Epoch 226]   Loss:    0.6191     Train Acc:     87.24%      Val Acc:      89.5%
# 2022-11-15 11:20:26 INFO     [Epoch 227]   Loss:    0.6173     Train Acc:      87.3%      Val Acc:      89.5%
# 2022-11-15 11:20:26 INFO     [Epoch 228]   Loss:    0.6155     Train Acc:     87.36%      Val Acc:      89.6%
# 2022-11-15 11:20:26 INFO     [Epoch 229]   Loss:    0.6137     Train Acc:     87.32%      Val Acc:      89.6%
# 2022-11-15 11:20:26 INFO     [Epoch 230]   Loss:    0.6119     Train Acc:     87.42%      Val Acc:      89.6%
# 2022-11-15 11:20:26 INFO     [Epoch 231]   Loss:    0.6101     Train Acc:     87.38%      Val Acc:      89.6%
# 2022-11-15 11:20:26 INFO     [Epoch 232]   Loss:    0.6084     Train Acc:     87.52%      Val Acc:      89.7%
# 2022-11-15 11:20:26 INFO     [Epoch 233]   Loss:    0.6066     Train Acc:     87.48%      Val Acc:      89.7%
# 2022-11-15 11:20:26 INFO     [Epoch 234]   Loss:    0.6049     Train Acc:      87.5%      Val Acc:      89.7%
# 2022-11-15 11:20:26 INFO     [Epoch 235]   Loss:    0.6032     Train Acc:     87.56%      Val Acc:      89.8%
# 2022-11-15 11:20:27 INFO     [Epoch 236]   Loss:    0.6014     Train Acc:     87.62%      Val Acc:      89.9%
# 2022-11-15 11:20:27 INFO     [Epoch 237]   Loss:    0.5998     Train Acc:      87.6%      Val Acc:      89.8%
# 2022-11-15 11:20:27 INFO     [Epoch 238]   Loss:    0.5981     Train Acc:      87.6%      Val Acc:      89.9%
# 2022-11-15 11:20:27 INFO     [Epoch 239]   Loss:    0.5964     Train Acc:      87.6%      Val Acc:      89.9%
# 2022-11-15 11:20:27 INFO     [Epoch 240]   Loss:    0.5947     Train Acc:     87.68%      Val Acc:      89.9%
# 2022-11-15 11:20:27 INFO     [Epoch 241]   Loss:    0.5931     Train Acc:     87.66%      Val Acc:      89.9%
# 2022-11-15 11:20:27 INFO     [Epoch 242]   Loss:    0.5915     Train Acc:     87.72%      Val Acc:      90.0%
# 2022-11-15 11:20:27 INFO     [Epoch 243]   Loss:    0.5899     Train Acc:     87.72%      Val Acc:      90.0%
# 2022-11-15 11:20:27 INFO     [Epoch 244]   Loss:    0.5882     Train Acc:      87.7%      Val Acc:      90.0%
# 2022-11-15 11:20:27 INFO     [Epoch 245]   Loss:    0.5867     Train Acc:     87.76%      Val Acc:      90.0%
# 2022-11-15 11:20:27 INFO     [Epoch 246]   Loss:    0.5851     Train Acc:     87.78%      Val Acc:      90.0%
# 2022-11-15 11:20:27 INFO     [Epoch 247]   Loss:    0.5835     Train Acc:     87.72%      Val Acc:      90.0%
# 2022-11-15 11:20:27 INFO     [Epoch 248]   Loss:    0.5819     Train Acc:     87.78%      Val Acc:      90.0%
# 2022-11-15 11:20:27 INFO     [Epoch 249]   Loss:    0.5804     Train Acc:      87.8%      Val Acc:      90.0%
# 2022-11-15 11:20:27 INFO     [Epoch 250]   Loss:    0.5789     Train Acc:      87.9%      Val Acc:      90.0%
# 2022-11-15 11:20:27 INFO     [Epoch 251]   Loss:    0.5773     Train Acc:     87.88%      Val Acc:      89.9%
# 2022-11-15 11:20:27 INFO     [Epoch 252]   Loss:    0.5758     Train Acc:     87.84%      Val Acc:      90.0%
# 2022-11-15 11:20:27 INFO     [Epoch 253]   Loss:    0.5743     Train Acc:      87.9%      Val Acc:      89.9%
# 2022-11-15 11:20:27 INFO     [Epoch 254]   Loss:    0.5728     Train Acc:     87.92%      Val Acc:      89.8%
# 2022-11-15 11:20:27 INFO     [Epoch 255]   Loss:    0.5713     Train Acc:     87.96%      Val Acc:      89.9%
# 2022-11-15 11:20:27 INFO     [Epoch 256]   Loss:    0.5698     Train Acc:     88.04%      Val Acc:      89.8%
# 2022-11-15 11:20:27 INFO     [Epoch 257]   Loss:    0.5684     Train Acc:      88.1%      Val Acc:      89.8%
# 2022-11-15 11:20:27 INFO     [Epoch 258]   Loss:    0.5669     Train Acc:     88.06%      Val Acc:      89.8%
# 2022-11-15 11:20:27 INFO     [Epoch 259]   Loss:    0.5655     Train Acc:     88.12%      Val Acc:      89.7%
# 2022-11-15 11:20:27 INFO     [Epoch 260]   Loss:    0.5641     Train Acc:     88.22%      Val Acc:      89.8%
# 2022-11-15 11:20:27 INFO     [Epoch 261]   Loss:    0.5627     Train Acc:      88.2%      Val Acc:      89.8%
# 2022-11-15 11:20:28 INFO     [Epoch 262]   Loss:    0.5613     Train Acc:     88.24%      Val Acc:      89.7%
# 2022-11-15 11:20:28 INFO     [Epoch 263]   Loss:    0.5598     Train Acc:      88.2%      Val Acc:      89.7%
# 2022-11-15 11:20:28 INFO     [Epoch 264]   Loss:    0.5585     Train Acc:     88.22%      Val Acc:      89.6%
# 2022-11-15 11:20:28 INFO     [Epoch 265]   Loss:     0.557     Train Acc:     88.24%      Val Acc:      89.7%
# 2022-11-15 11:20:28 INFO     [Epoch 266]   Loss:    0.5557     Train Acc:     88.26%      Val Acc:      89.8%
# 2022-11-15 11:20:28 INFO     [Epoch 267]   Loss:    0.5544     Train Acc:     88.22%      Val Acc:      89.7%
# 2022-11-15 11:20:28 INFO     [Epoch 268]   Loss:     0.553     Train Acc:     88.28%      Val Acc:      89.7%
# 2022-11-15 11:20:28 INFO     [Epoch 269]   Loss:    0.5516     Train Acc:     88.24%      Val Acc:      89.7%
# 2022-11-15 11:20:28 INFO     [Epoch 270]   Loss:    0.5503     Train Acc:     88.26%      Val Acc:      89.7%
# 2022-11-15 11:20:28 INFO     [Epoch 271]   Loss:    0.5489     Train Acc:     88.32%      Val Acc:      89.7%
# 2022-11-15 11:20:28 INFO     [Epoch 272]   Loss:    0.5476     Train Acc:     88.32%      Val Acc:      89.7%
# 2022-11-15 11:20:28 INFO     [Epoch 273]   Loss:    0.5463     Train Acc:     88.32%      Val Acc:      89.8%
# 2022-11-15 11:20:28 INFO     [Epoch 274]   Loss:     0.545     Train Acc:     88.42%      Val Acc:      89.7%
# 2022-11-15 11:20:28 INFO     [Epoch 275]   Loss:    0.5437     Train Acc:     88.34%      Val Acc:      89.7%
# 2022-11-15 11:20:28 INFO     [Epoch 276]   Loss:    0.5424     Train Acc:     88.44%      Val Acc:      89.8%
# 2022-11-15 11:20:28 INFO     [Epoch 277]   Loss:    0.5412     Train Acc:     88.38%      Val Acc:      89.8%
# 2022-11-15 11:20:28 INFO     [Epoch 278]   Loss:    0.5399     Train Acc:      88.4%      Val Acc:      89.8%
# 2022-11-15 11:20:28 INFO     [Epoch 279]   Loss:    0.5387     Train Acc:     88.48%      Val Acc:      89.8%
# 2022-11-15 11:20:28 INFO     [Epoch 280]   Loss:    0.5374     Train Acc:     88.48%      Val Acc:      89.8%
# 2022-11-15 11:20:28 INFO     [Epoch 281]   Loss:    0.5362     Train Acc:     88.56%      Val Acc:      89.9%
# 2022-11-15 11:20:28 INFO     [Epoch 282]   Loss:    0.5349     Train Acc:     88.52%      Val Acc:      89.8%
# 2022-11-15 11:20:28 INFO     [Epoch 283]   Loss:    0.5337     Train Acc:     88.54%      Val Acc:      89.7%
# 2022-11-15 11:20:28 INFO     [Epoch 284]   Loss:    0.5325     Train Acc:      88.5%      Val Acc:      89.7%
# 2022-11-15 11:20:28 INFO     [Epoch 285]   Loss:    0.5312     Train Acc:      88.5%      Val Acc:      89.8%
# 2022-11-15 11:20:28 INFO     [Epoch 286]   Loss:    0.5301     Train Acc:     88.56%      Val Acc:      89.7%
# 2022-11-15 11:20:28 INFO     [Epoch 287]   Loss:    0.5289     Train Acc:     88.58%      Val Acc:      89.7%
# 2022-11-15 11:20:29 INFO     [Epoch 288]   Loss:    0.5277     Train Acc:     88.56%      Val Acc:      89.8%
# 2022-11-15 11:20:29 INFO     [Epoch 289]   Loss:    0.5265     Train Acc:     88.66%      Val Acc:      89.8%
# 2022-11-15 11:20:29 INFO     [Epoch 290]   Loss:    0.5253     Train Acc:     88.68%      Val Acc:      89.9%
# 2022-11-15 11:20:29 INFO     [Epoch 291]   Loss:    0.5242     Train Acc:     88.64%      Val Acc:      89.8%
# 2022-11-15 11:20:29 INFO     [Epoch 292]   Loss:     0.523     Train Acc:      88.7%      Val Acc:      90.0%
# 2022-11-15 11:20:29 INFO     [Epoch 293]   Loss:    0.5219     Train Acc:     88.72%      Val Acc:      90.0%
# 2022-11-15 11:20:29 INFO     [Epoch 294]   Loss:    0.5207     Train Acc:     88.74%      Val Acc:      90.0%
# 2022-11-15 11:20:29 INFO     [Epoch 295]   Loss:    0.5196     Train Acc:     88.74%      Val Acc:      90.0%
# 2022-11-15 11:20:29 INFO     [Epoch 296]   Loss:    0.5185     Train Acc:     88.78%      Val Acc:      90.1%
# 2022-11-15 11:20:29 INFO     [Epoch 297]   Loss:    0.5174     Train Acc:     88.72%      Val Acc:      90.0%
# 2022-11-15 11:20:29 INFO     [Epoch 298]   Loss:    0.5162     Train Acc:      88.8%      Val Acc:      90.0%
# 2022-11-15 11:20:29 INFO     [Epoch 299]   Loss:    0.5151     Train Acc:     88.78%      Val Acc:      90.0%
# 2022-11-15 11:20:29 INFO     [Epoch 300]   Loss:     0.514     Train Acc:     88.82%      Val Acc:      90.0%
# 2022-11-15 11:20:29 INFO     [Epoch 301]   Loss:    0.5129     Train Acc:     88.76%      Val Acc:      90.1%
# 2022-11-15 11:20:29 INFO     [Epoch 302]   Loss:    0.5118     Train Acc:     88.88%      Val Acc:      90.1%
# 2022-11-15 11:20:29 INFO     [Epoch 303]   Loss:    0.5107     Train Acc:     88.88%      Val Acc:      90.1%
# 2022-11-15 11:20:29 INFO     [Epoch 304]   Loss:    0.5097     Train Acc:     88.84%      Val Acc:      90.1%
# 2022-11-15 11:20:29 INFO     [Epoch 305]   Loss:    0.5086     Train Acc:     88.84%      Val Acc:      90.1%
# 2022-11-15 11:20:29 INFO     [Epoch 306]   Loss:    0.5076     Train Acc:      88.9%      Val Acc:      90.1%
# 2022-11-15 11:20:29 INFO     [Epoch 307]   Loss:    0.5065     Train Acc:     88.86%      Val Acc:      90.1%
# 2022-11-15 11:20:29 INFO     [Epoch 308]   Loss:    0.5054     Train Acc:     88.94%      Val Acc:      90.1%
# 2022-11-15 11:20:29 INFO     [Epoch 309]   Loss:    0.5044     Train Acc:     88.96%      Val Acc:      90.2%
# 2022-11-15 11:20:29 INFO     [Epoch 310]   Loss:    0.5034     Train Acc:      88.9%      Val Acc:      90.2%
# 2022-11-15 11:20:29 INFO     [Epoch 311]   Loss:    0.5024     Train Acc:     88.88%      Val Acc:      90.1%
# 2022-11-15 11:20:29 INFO     [Epoch 312]   Loss:    0.5014     Train Acc:     88.96%      Val Acc:      90.2%
# 2022-11-15 11:20:29 INFO     [Epoch 313]   Loss:    0.5003     Train Acc:     88.92%      Val Acc:      90.2%
# 2022-11-15 11:20:29 INFO     [Epoch 314]   Loss:    0.4993     Train Acc:     88.94%      Val Acc:      90.1%
# 2022-11-15 11:20:29 INFO     [Epoch 315]   Loss:    0.4983     Train Acc:     88.96%      Val Acc:      90.3%
# 2022-11-15 11:20:30 INFO     [Epoch 316]   Loss:    0.4973     Train Acc:     88.96%      Val Acc:      90.3%
# 2022-11-15 11:20:30 INFO     [Epoch 317]   Loss:    0.4963     Train Acc:     88.96%      Val Acc:      90.3%
# 2022-11-15 11:20:30 INFO     [Epoch 318]   Loss:    0.4953     Train Acc:     89.06%      Val Acc:      90.3%
# 2022-11-15 11:20:30 INFO     [Epoch 319]   Loss:    0.4943     Train Acc:     89.06%      Val Acc:      90.3%
# 2022-11-15 11:20:30 INFO     [Epoch 320]   Loss:    0.4934     Train Acc:     89.02%      Val Acc:      90.3%
# 2022-11-15 11:20:30 INFO     [Epoch 321]   Loss:    0.4924     Train Acc:     89.06%      Val Acc:      90.3%
# 2022-11-15 11:20:30 INFO     [Epoch 322]   Loss:    0.4915     Train Acc:     89.02%      Val Acc:      90.3%
# 2022-11-15 11:20:30 INFO     [Epoch 323]   Loss:    0.4905     Train Acc:      89.0%      Val Acc:      90.3%
# 2022-11-15 11:20:30 INFO     [Epoch 324]   Loss:    0.4895     Train Acc:     89.08%      Val Acc:      90.3%
# 2022-11-15 11:20:30 INFO     [Epoch 325]   Loss:    0.4885     Train Acc:     89.08%      Val Acc:      90.3%
# 2022-11-15 11:20:30 INFO     [Epoch 326]   Loss:    0.4876     Train Acc:      89.1%      Val Acc:      90.4%
# 2022-11-15 11:20:30 INFO     [Epoch 327]   Loss:    0.4867     Train Acc:     89.08%      Val Acc:      90.4%
# 2022-11-15 11:20:30 INFO     [Epoch 328]   Loss:    0.4857     Train Acc:      89.1%      Val Acc:      90.4%
# 2022-11-15 11:20:30 INFO     [Epoch 329]   Loss:    0.4848     Train Acc:      89.2%      Val Acc:      90.4%
# 2022-11-15 11:20:30 INFO     [Epoch 330]   Loss:    0.4839     Train Acc:      89.2%      Val Acc:      90.4%
# 2022-11-15 11:20:30 INFO     [Epoch 331]   Loss:     0.483     Train Acc:     89.24%      Val Acc:      90.4%
# 2022-11-15 11:20:30 INFO     [Epoch 332]   Loss:    0.4821     Train Acc:     89.22%      Val Acc:      90.4%
# 2022-11-15 11:20:30 INFO     [Epoch 333]   Loss:    0.4812     Train Acc:     89.24%      Val Acc:      90.4%
# 2022-11-15 11:20:30 INFO     [Epoch 334]   Loss:    0.4803     Train Acc:     89.24%      Val Acc:      90.5%
# 2022-11-15 11:20:30 INFO     [Epoch 335]   Loss:    0.4794     Train Acc:     89.26%      Val Acc:      90.5%
# 2022-11-15 11:20:30 INFO     [Epoch 336]   Loss:    0.4785     Train Acc:      89.3%      Val Acc:      90.5%
# 2022-11-15 11:20:30 INFO     [Epoch 337]   Loss:    0.4776     Train Acc:      89.3%      Val Acc:      90.5%
# 2022-11-15 11:20:30 INFO     [Epoch 338]   Loss:    0.4767     Train Acc:     89.32%      Val Acc:      90.4%
# 2022-11-15 11:20:30 INFO     [Epoch 339]   Loss:    0.4759     Train Acc:     89.36%      Val Acc:      90.5%
# 2022-11-15 11:20:31 INFO     [Epoch 340]   Loss:     0.475     Train Acc:     89.42%      Val Acc:      90.5%
# 2022-11-15 11:20:31 INFO     [Epoch 341]   Loss:    0.4741     Train Acc:     89.38%      Val Acc:      90.4%
# 2022-11-15 11:20:31 INFO     [Epoch 342]   Loss:    0.4732     Train Acc:     89.36%      Val Acc:      90.4%
# 2022-11-15 11:20:31 INFO     [Epoch 343]   Loss:    0.4724     Train Acc:     89.42%      Val Acc:      90.4%
# 2022-11-15 11:20:31 INFO     [Epoch 344]   Loss:    0.4716     Train Acc:     89.42%      Val Acc:      90.4%
# 2022-11-15 11:20:31 INFO     [Epoch 345]   Loss:    0.4707     Train Acc:     89.38%      Val Acc:      90.4%
# 2022-11-15 11:20:31 INFO     [Epoch 346]   Loss:    0.4699     Train Acc:     89.54%      Val Acc:      90.4%
# 2022-11-15 11:20:31 INFO     [Epoch 347]   Loss:     0.469     Train Acc:     89.44%      Val Acc:      90.4%
# 2022-11-15 11:20:31 INFO     [Epoch 348]   Loss:    0.4682     Train Acc:     89.44%      Val Acc:      90.4%
# 2022-11-15 11:20:31 INFO     [Epoch 349]   Loss:    0.4673     Train Acc:     89.48%      Val Acc:      90.4%
# 2022-11-15 11:20:31 INFO     [Epoch 350]   Loss:    0.4666     Train Acc:     89.48%      Val Acc:      90.3%
# 2022-11-15 11:20:31 INFO     [Epoch 351]   Loss:    0.4658     Train Acc:     89.54%      Val Acc:      90.3%
# 2022-11-15 11:20:31 INFO     [Epoch 352]   Loss:    0.4649     Train Acc:      89.5%      Val Acc:      90.3%
# 2022-11-15 11:20:31 INFO     [Epoch 353]   Loss:    0.4641     Train Acc:     89.62%      Val Acc:      90.3%
# 2022-11-15 11:20:31 INFO     [Epoch 354]   Loss:    0.4633     Train Acc:     89.62%      Val Acc:      90.3%
# 2022-11-15 11:20:31 INFO     [Epoch 355]   Loss:    0.4625     Train Acc:      89.6%      Val Acc:      90.3%
# 2022-11-15 11:20:31 INFO     [Epoch 356]   Loss:    0.4617     Train Acc:     89.64%      Val Acc:      90.3%
# 2022-11-15 11:20:31 INFO     [Epoch 357]   Loss:    0.4609     Train Acc:     89.58%      Val Acc:      90.3%
# 2022-11-15 11:20:31 INFO     [Epoch 358]   Loss:    0.4601     Train Acc:     89.62%      Val Acc:      90.3%
# 2022-11-15 11:20:31 INFO     [Epoch 359]   Loss:    0.4593     Train Acc:     89.62%      Val Acc:      90.3%
# 2022-11-15 11:20:31 INFO     [Epoch 360]   Loss:    0.4585     Train Acc:     89.56%      Val Acc:      90.3%
# 2022-11-15 11:20:31 INFO     [Epoch 361]   Loss:    0.4578     Train Acc:     89.66%      Val Acc:      90.3%
# 2022-11-15 11:20:31 INFO     [Epoch 362]   Loss:     0.457     Train Acc:      89.6%      Val Acc:      90.4%
# 2022-11-15 11:20:32 INFO     [Epoch 363]   Loss:    0.4562     Train Acc:      89.7%      Val Acc:      90.4%
# 2022-11-15 11:20:32 INFO     [Epoch 364]   Loss:    0.4554     Train Acc:     89.68%      Val Acc:      90.4%
# 2022-11-15 11:20:32 INFO     [Epoch 365]   Loss:    0.4547     Train Acc:     89.68%      Val Acc:      90.4%
# 2022-11-15 11:20:32 INFO     [Epoch 366]   Loss:    0.4539     Train Acc:     89.72%      Val Acc:      90.5%
# 2022-11-15 11:20:32 INFO     [Epoch 367]   Loss:    0.4532     Train Acc:      89.7%      Val Acc:      90.5%
# 2022-11-15 11:20:32 INFO     [Epoch 368]   Loss:    0.4525     Train Acc:     89.76%      Val Acc:      90.5%
# 2022-11-15 11:20:32 INFO     [Epoch 369]   Loss:    0.4517     Train Acc:     89.82%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 370]   Loss:    0.4509     Train Acc:     89.86%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 371]   Loss:    0.4502     Train Acc:     89.88%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 372]   Loss:    0.4495     Train Acc:     89.86%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 373]   Loss:    0.4487     Train Acc:      89.9%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 374]   Loss:     0.448     Train Acc:     89.86%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 375]   Loss:    0.4473     Train Acc:     89.86%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 376]   Loss:    0.4466     Train Acc:      89.9%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 377]   Loss:    0.4459     Train Acc:     89.88%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 378]   Loss:    0.4452     Train Acc:     89.92%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 379]   Loss:    0.4444     Train Acc:     89.94%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 380]   Loss:    0.4437     Train Acc:     89.94%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 381]   Loss:    0.4431     Train Acc:     89.96%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 382]   Loss:    0.4423     Train Acc:      89.9%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 383]   Loss:    0.4416     Train Acc:     89.96%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 384]   Loss:    0.4409     Train Acc:      90.0%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 385]   Loss:    0.4402     Train Acc:     89.92%      Val Acc:      90.7%
# 2022-11-15 11:20:32 INFO     [Epoch 386]   Loss:    0.4395     Train Acc:     90.04%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 387]   Loss:    0.4389     Train Acc:     89.98%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 388]   Loss:    0.4382     Train Acc:      90.1%      Val Acc:      90.7%
# 2022-11-15 11:20:32 INFO     [Epoch 389]   Loss:    0.4375     Train Acc:     90.08%      Val Acc:      90.7%
# 2022-11-15 11:20:32 INFO     [Epoch 390]   Loss:    0.4369     Train Acc:     90.12%      Val Acc:      90.6%
# 2022-11-15 11:20:32 INFO     [Epoch 391]   Loss:    0.4362     Train Acc:     90.16%      Val Acc:      90.7%
# 2022-11-15 11:20:33 INFO     [Epoch 392]   Loss:    0.4355     Train Acc:     90.08%      Val Acc:      90.7%
# 2022-11-15 11:20:33 INFO     [Epoch 393]   Loss:    0.4349     Train Acc:     90.16%      Val Acc:      90.7%
# 2022-11-15 11:20:33 INFO     [Epoch 394]   Loss:    0.4342     Train Acc:     90.18%      Val Acc:      90.8%
# 2022-11-15 11:20:33 INFO     [Epoch 395]   Loss:    0.4335     Train Acc:     90.14%      Val Acc:      90.8%
# 2022-11-15 11:20:33 INFO     [Epoch 396]   Loss:    0.4329     Train Acc:     90.18%      Val Acc:      90.7%
# 2022-11-15 11:20:33 INFO     [Epoch 397]   Loss:    0.4323     Train Acc:     90.18%      Val Acc:      90.7%
# 2022-11-15 11:20:33 INFO     [Epoch 398]   Loss:    0.4316     Train Acc:     90.18%      Val Acc:      90.7%
# 2022-11-15 11:20:33 INFO     [Epoch 399]   Loss:    0.4309     Train Acc:      90.2%      Val Acc:      90.9%
# 2022-11-15 11:20:33 INFO     [Epoch 400]   Loss:    0.4303     Train Acc:     90.16%      Val Acc:      90.8%
# 2022-11-15 11:20:33 INFO     [Epoch 401]   Loss:    0.4297     Train Acc:     90.24%      Val Acc:      90.8%
# 2022-11-15 11:20:33 INFO     [Epoch 402]   Loss:     0.429     Train Acc:     90.26%      Val Acc:      90.8%
# 2022-11-15 11:20:33 INFO     [Epoch 403]   Loss:    0.4284     Train Acc:     90.24%      Val Acc:      90.8%
# 2022-11-15 11:20:33 INFO     [Epoch 404]   Loss:    0.4278     Train Acc:     90.22%      Val Acc:      90.8%
# 2022-11-15 11:20:33 INFO     [Epoch 405]   Loss:    0.4271     Train Acc:     90.26%      Val Acc:      90.8%
# 2022-11-15 11:20:33 INFO     [Epoch 406]   Loss:    0.4265     Train Acc:     90.26%      Val Acc:      90.8%
# 2022-11-15 11:20:33 INFO     [Epoch 407]   Loss:    0.4259     Train Acc:     90.32%      Val Acc:      90.9%
# 2022-11-15 11:20:33 INFO     [Epoch 408]   Loss:    0.4253     Train Acc:     90.24%      Val Acc:      90.8%
# 2022-11-15 11:20:33 INFO     [Epoch 409]   Loss:    0.4247     Train Acc:     90.24%      Val Acc:      90.9%
# 2022-11-15 11:20:33 INFO     [Epoch 410]   Loss:     0.424     Train Acc:     90.32%      Val Acc:      90.8%
# 2022-11-15 11:20:33 INFO     [Epoch 411]   Loss:    0.4235     Train Acc:     90.28%      Val Acc:      90.9%
# ...
# 2022-11-15 11:21:21 INFO     [Epoch 1856]   Loss:    0.1881     Train Acc:     95.38%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1857]   Loss:    0.1881     Train Acc:     95.42%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1858]   Loss:     0.188     Train Acc:      95.4%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1859]   Loss:     0.188     Train Acc:     95.44%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1860]   Loss:    0.1879     Train Acc:     95.38%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1861]   Loss:    0.1879     Train Acc:     95.42%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1862]   Loss:    0.1878     Train Acc:      95.4%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1863]   Loss:    0.1877     Train Acc:     95.44%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1864]   Loss:    0.1877     Train Acc:      95.4%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1865]   Loss:    0.1876     Train Acc:     95.42%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1866]   Loss:    0.1876     Train Acc:     95.38%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1867]   Loss:    0.1875     Train Acc:      95.4%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1868]   Loss:    0.1874     Train Acc:      95.4%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1869]   Loss:    0.1874     Train Acc:     95.42%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1870]   Loss:    0.1873     Train Acc:     95.44%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1871]   Loss:    0.1872     Train Acc:      95.4%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1872]   Loss:    0.1872     Train Acc:     95.38%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1873]   Loss:    0.1871     Train Acc:     95.44%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1874]   Loss:    0.1871     Train Acc:     95.44%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1875]   Loss:     0.187     Train Acc:      95.4%      Val Acc:      92.5%
# 2022-11-15 11:21:22 INFO     [Epoch 1876]   Loss:     0.187     Train Acc:     95.48%      Val Acc:      92.5%
# 2022-11-15 11:21:22 INFO     [Epoch 1877]   Loss:    0.1869     Train Acc:     95.48%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1878]   Loss:    0.1868     Train Acc:      95.4%      Val Acc:      92.5%
# 2022-11-15 11:21:22 INFO     [Epoch 1879]   Loss:    0.1868     Train Acc:     95.42%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1880]   Loss:    0.1867     Train Acc:      95.4%      Val Acc:      92.5%
# 2022-11-15 11:21:22 INFO     [Epoch 1881]   Loss:    0.1866     Train Acc:     95.44%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1882]   Loss:    0.1866     Train Acc:     95.48%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1883]   Loss:    0.1865     Train Acc:     95.42%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1884]   Loss:    0.1865     Train Acc:     95.42%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1885]   Loss:    0.1864     Train Acc:     95.44%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1886]   Loss:    0.1864     Train Acc:     95.42%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1887]   Loss:    0.1863     Train Acc:     95.46%      Val Acc:      92.4%
# 2022-11-15 11:21:22 INFO     [Epoch 1888]   Loss:    0.1862     Train Acc:     95.46%      Val Acc:      92.5%
# 2022-11-15 11:21:23 INFO     [Epoch 1889]   Loss:    0.1862     Train Acc:     95.46%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1890]   Loss:    0.1861     Train Acc:     95.48%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1891]   Loss:    0.1861     Train Acc:     95.48%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1892]   Loss:     0.186     Train Acc:      95.4%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1893]   Loss:     0.186     Train Acc:     95.46%      Val Acc:      92.5%
# 2022-11-15 11:21:23 INFO     [Epoch 1894]   Loss:    0.1859     Train Acc:     95.46%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1895]   Loss:    0.1859     Train Acc:     95.44%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1896]   Loss:    0.1858     Train Acc:     95.46%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1897]   Loss:    0.1857     Train Acc:     95.48%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1898]   Loss:    0.1857     Train Acc:     95.46%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1899]   Loss:    0.1856     Train Acc:     95.44%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1900]   Loss:    0.1856     Train Acc:     95.44%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1901]   Loss:    0.1855     Train Acc:     95.54%      Val Acc:      92.5%
# 2022-11-15 11:21:23 INFO     [Epoch 1902]   Loss:    0.1854     Train Acc:     95.46%      Val Acc:      92.5%
# 2022-11-15 11:21:23 INFO     [Epoch 1903]   Loss:    0.1853     Train Acc:     95.46%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1904]   Loss:    0.1853     Train Acc:     95.44%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1905]   Loss:    0.1852     Train Acc:     95.48%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1906]   Loss:    0.1852     Train Acc:     95.48%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1907]   Loss:    0.1851     Train Acc:     95.48%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1908]   Loss:    0.1851     Train Acc:     95.42%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1909]   Loss:     0.185     Train Acc:      95.5%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1910]   Loss:    0.1849     Train Acc:     95.48%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1911]   Loss:    0.1849     Train Acc:     95.54%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1912]   Loss:    0.1848     Train Acc:     95.52%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1913]   Loss:    0.1848     Train Acc:     95.48%      Val Acc:      92.5%
# 2022-11-15 11:21:23 INFO     [Epoch 1914]   Loss:    0.1847     Train Acc:      95.5%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1915]   Loss:    0.1846     Train Acc:     95.48%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1916]   Loss:    0.1846     Train Acc:     95.48%      Val Acc:      92.4%
# 2022-11-15 11:21:23 INFO     [Epoch 1917]   Loss:    0.1845     Train Acc:     95.48%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1918]   Loss:    0.1845     Train Acc:     95.54%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1919]   Loss:    0.1844     Train Acc:      95.5%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1920]   Loss:    0.1844     Train Acc:     95.52%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1921]   Loss:    0.1843     Train Acc:     95.54%      Val Acc:      92.5%
# 2022-11-15 11:21:24 INFO     [Epoch 1922]   Loss:    0.1843     Train Acc:      95.5%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1923]   Loss:    0.1842     Train Acc:     95.52%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1924]   Loss:    0.1841     Train Acc:     95.54%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1925]   Loss:    0.1841     Train Acc:      95.5%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1926]   Loss:     0.184     Train Acc:     95.54%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1927]   Loss:     0.184     Train Acc:      95.5%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1928]   Loss:    0.1839     Train Acc:     95.54%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1929]   Loss:    0.1839     Train Acc:      95.5%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1930]   Loss:    0.1838     Train Acc:     95.54%      Val Acc:      92.5%
# 2022-11-15 11:21:24 INFO     [Epoch 1931]   Loss:    0.1837     Train Acc:     95.54%      Val Acc:      92.5%
# 2022-11-15 11:21:24 INFO     [Epoch 1932]   Loss:    0.1837     Train Acc:      95.5%      Val Acc:      92.5%
# 2022-11-15 11:21:24 INFO     [Epoch 1933]   Loss:    0.1837     Train Acc:     95.48%      Val Acc:      92.5%
# 2022-11-15 11:21:24 INFO     [Epoch 1934]   Loss:    0.1835     Train Acc:     95.56%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1935]   Loss:    0.1835     Train Acc:      95.5%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1936]   Loss:    0.1835     Train Acc:     95.54%      Val Acc:      92.5%
# 2022-11-15 11:21:24 INFO     [Epoch 1937]   Loss:    0.1834     Train Acc:     95.54%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1938]   Loss:    0.1833     Train Acc:     95.52%      Val Acc:      92.5%
# 2022-11-15 11:21:24 INFO     [Epoch 1939]   Loss:    0.1833     Train Acc:     95.54%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1940]   Loss:    0.1832     Train Acc:     95.54%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1941]   Loss:    0.1832     Train Acc:     95.56%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1942]   Loss:    0.1831     Train Acc:     95.58%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1943]   Loss:     0.183     Train Acc:     95.54%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1944]   Loss:     0.183     Train Acc:     95.56%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1945]   Loss:    0.1829     Train Acc:     95.52%      Val Acc:      92.4%
# 2022-11-15 11:21:24 INFO     [Epoch 1946]   Loss:    0.1829     Train Acc:     95.54%      Val Acc:      92.4%
# 2022-11-15 11:21:25 INFO     [Epoch 1947]   Loss:    0.1828     Train Acc:     95.54%      Val Acc:      92.4%
# 2022-11-15 11:21:25 INFO     [Epoch 1948]   Loss:    0.1828     Train Acc:     95.56%      Val Acc:      92.4%
# 2022-11-15 11:21:25 INFO     [Epoch 1949]   Loss:    0.1827     Train Acc:     95.56%      Val Acc:      92.4%
# 2022-11-15 11:21:25 INFO     [Epoch 1950]   Loss:    0.1827     Train Acc:     95.56%      Val Acc:      92.5%
# 2022-11-15 11:21:25 INFO     [Epoch 1951]   Loss:    0.1826     Train Acc:     95.58%      Val Acc:      92.6%
# 2022-11-15 11:21:25 INFO     [Epoch 1952]   Loss:    0.1825     Train Acc:     95.54%      Val Acc:      92.6%
# 2022-11-15 11:21:25 INFO     [Epoch 1953]   Loss:    0.1825     Train Acc:      95.6%      Val Acc:      92.4%
# 2022-11-15 11:21:25 INFO     [Epoch 1954]   Loss:    0.1824     Train Acc:     95.56%      Val Acc:      92.4%
# 2022-11-15 11:21:25 INFO     [Epoch 1955]   Loss:    0.1823     Train Acc:     95.58%      Val Acc:      92.4%
# 2022-11-15 11:21:25 INFO     [Epoch 1956]   Loss:    0.1823     Train Acc:     95.58%      Val Acc:      92.5%
# 2022-11-15 11:21:25 INFO     [Epoch 1957]   Loss:    0.1823     Train Acc:     95.56%      Val Acc:      92.4%
# 2022-11-15 11:21:25 INFO     [Epoch 1958]   Loss:    0.1822     Train Acc:     95.54%      Val Acc:      92.4%
# 2022-11-15 11:21:25 INFO     [Epoch 1959]   Loss:    0.1821     Train Acc:     95.58%      Val Acc:      92.5%
# 2022-11-15 11:21:25 INFO     [Epoch 1960]   Loss:    0.1821     Train Acc:     95.56%      Val Acc:      92.4%
# 2022-11-15 11:21:25 INFO     [Epoch 1961]   Loss:     0.182     Train Acc:     95.56%      Val Acc:      92.6%
# 2022-11-15 11:21:25 INFO     [Epoch 1962]   Loss:     0.182     Train Acc:     95.54%      Val Acc:      92.4%
# 2022-11-15 11:21:25 INFO     [Epoch 1963]   Loss:    0.1819     Train Acc:     95.56%      Val Acc:      92.4%
# 2022-11-15 11:21:25 INFO     [Epoch 1964]   Loss:    0.1819     Train Acc:     95.58%      Val Acc:      92.6%
# 2022-11-15 11:21:25 INFO     [Epoch 1965]   Loss:    0.1818     Train Acc:     95.58%      Val Acc:      92.4%
# 2022-11-15 11:21:25 INFO     [Epoch 1966]   Loss:    0.1817     Train Acc:     95.56%      Val Acc:      92.4%
# 2022-11-15 11:21:25 INFO     [Epoch 1967]   Loss:    0.1817     Train Acc:     95.56%      Val Acc:      92.4%
# 2022-11-15 11:21:25 INFO     [Epoch 1968]   Loss:    0.1817     Train Acc:      95.6%      Val Acc:      92.6%
# 2022-11-15 11:21:25 INFO     [Epoch 1969]   Loss:    0.1816     Train Acc:     95.64%      Val Acc:      92.7%
# 2022-11-15 11:21:25 INFO     [Epoch 1970]   Loss:    0.1815     Train Acc:     95.58%      Val Acc:      92.6%
# 2022-11-15 11:21:25 INFO     [Epoch 1971]   Loss:    0.1814     Train Acc:      95.6%      Val Acc:      92.7%
# 2022-11-15 11:21:25 INFO     [Epoch 1972]   Loss:    0.1815     Train Acc:      95.6%      Val Acc:      92.7%
# 2022-11-15 11:21:25 INFO     [Epoch 1973]   Loss:    0.1814     Train Acc:     95.62%      Val Acc:      92.6%
# 2022-11-15 11:21:25 INFO     [Epoch 1974]   Loss:    0.1813     Train Acc:     95.62%      Val Acc:      92.6%
# 2022-11-15 11:21:25 INFO     [Epoch 1975]   Loss:    0.1812     Train Acc:      95.6%      Val Acc:      92.7%
# 2022-11-15 11:21:25 INFO     [Epoch 1976]   Loss:    0.1812     Train Acc:     95.56%      Val Acc:      92.7%
# 2022-11-15 11:21:25 INFO     [Epoch 1977]   Loss:    0.1811     Train Acc:     95.62%      Val Acc:      92.7%
# 2022-11-15 11:21:26 INFO     [Epoch 1978]   Loss:    0.1811     Train Acc:     95.62%      Val Acc:      92.7%
# 2022-11-15 11:21:26 INFO     [Epoch 1979]   Loss:     0.181     Train Acc:     95.64%      Val Acc:      92.7%
# 2022-11-15 11:21:26 INFO     [Epoch 1980]   Loss:     0.181     Train Acc:     95.58%      Val Acc:      92.8%
# 2022-11-15 11:21:26 INFO     [Epoch 1981]   Loss:    0.1809     Train Acc:      95.6%      Val Acc:      92.8%
# 2022-11-15 11:21:26 INFO     [Epoch 1982]   Loss:    0.1808     Train Acc:      95.6%      Val Acc:      92.8%
# 2022-11-15 11:21:26 INFO     [Epoch 1983]   Loss:    0.1808     Train Acc:     95.62%      Val Acc:      92.8%
# 2022-11-15 11:21:26 INFO     [Epoch 1984]   Loss:    0.1807     Train Acc:     95.56%      Val Acc:      92.8%
# 2022-11-15 11:21:26 INFO     [Epoch 1985]   Loss:    0.1807     Train Acc:      95.6%      Val Acc:      92.7%
# 2022-11-15 11:21:26 INFO     [Epoch 1986]   Loss:    0.1806     Train Acc:      95.6%      Val Acc:      92.6%
# 2022-11-15 11:21:26 INFO     [Epoch 1987]   Loss:    0.1806     Train Acc:     95.62%      Val Acc:      92.7%
# 2022-11-15 11:21:26 INFO     [Epoch 1988]   Loss:    0.1805     Train Acc:     95.68%      Val Acc:      92.8%
# 2022-11-15 11:21:26 INFO     [Epoch 1989]   Loss:    0.1805     Train Acc:     95.64%      Val Acc:      92.7%
# 2022-11-15 11:21:26 INFO     [Epoch 1990]   Loss:    0.1804     Train Acc:     95.64%      Val Acc:      92.7%
# 2022-11-15 11:21:26 INFO     [Epoch 1991]   Loss:    0.1804     Train Acc:     95.58%      Val Acc:      92.7%
# 2022-11-15 11:21:26 INFO     [Epoch 1992]   Loss:    0.1803     Train Acc:     95.62%      Val Acc:      92.7%
# 2022-11-15 11:21:26 INFO     [Epoch 1993]   Loss:    0.1803     Train Acc:     95.64%      Val Acc:      92.7%
# 2022-11-15 11:21:26 INFO     [Epoch 1994]   Loss:    0.1802     Train Acc:      95.6%      Val Acc:      92.6%
# 2022-11-15 11:21:26 INFO     [Epoch 1995]   Loss:    0.1801     Train Acc:     95.64%      Val Acc:      92.7%
# 2022-11-15 11:21:26 INFO     [Epoch 1996]   Loss:    0.1801     Train Acc:     95.62%      Val Acc:      92.7%
# 2022-11-15 11:21:26 INFO     [Epoch 1997]   Loss:      0.18     Train Acc:     95.64%      Val Acc:      92.7%
# 2022-11-15 11:21:26 INFO     [Epoch 1998]   Loss:      0.18     Train Acc:     95.62%      Val Acc:      92.7%
# 2022-11-15 11:21:26 INFO     [Epoch 1999]   Loss:    0.1799     Train Acc:     95.66%      Val Acc:      92.7%
